# %% [markdown]
# # Libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Option Setting

# %%
# Setting options for readability
pd.set_option("max_colwidth", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Loading Dataframes

# %%
# Loading data dictionary to understand the column definitions
data_dictionary = pd.read_csv('data_dictionary.csv')

# Viewing data_dictionary
data_dictionary
# Out:
#                     Field  \
# 0                VendorID
# 1    lpep_pickup_datetime
# 2   lpep_dropoff_datetime
# 3      store_and_fwd_flag
# 4              RatecodeID
# 5            PULocationID
# 6            DOLocationID
# 7         passenger_count
# 8           trip_distance
# 9             fare_amount
# 10                  extra
# 11                mta_tax
# 12             tip_amount
# 13           tolls_amount
# 14  improvement_surcharge
# 15           total_amount
# 16           payment_type
# 17              trip_type
# 18   congestion_surcharge
#
#                                                                                                                                                                                                                                                Description
# 0                                                                                                                                    A code indicating the LPEP provider that provided the record (1= Creative Mobile Technologies, LLC; 2= Verifone Inc.)
# 1                                                                                                                                                                                                             The date and time when the meter was engaged
# 2                                                                                                                                                                                                          The date and time when the meter was disengaged
# 3   This flag indicates whether the trip record was held in vehicle memory before sending to the vendor, aka �store and forward,� because the vehicle did not have a connection to the server (Y= store and forward trip; N= not a store and forward trip)
# 4                                                                                                  The final rate code in effect at the end of the trip (1= Standard rate; 2= JFK; 3= Newark; 4= Nassau or Westchester; 5= Negotiated fare; 6= Group ride)
# 5                                                                                                                                                                                                         TLC Taxi Zone in which the taximeter was engaged
# 6                                                                                                                                                                                                      TLC Taxi Zone in which the taximeter was disengaged
# 7                                                                                                                                                                                 The number of passengers in the vehicle (this is a driver entered value)
# 8                                                                                                                                                                                             The elapsed trip distance in miles reported by the taximeter
# 9                                                                                                                                                                                                       The time-and-distance fare calculated by the meter
# 10                                                                                                                                               Miscellaneous extras and surcharges (this only includes the $0.50 and $1 rush hour and overnight charges)
# 11                                                                                                                                                                          $0.50 MTA tax that is automatically triggered based on the metered rate in use
# 12                                                                                                                                                                  Tip amount (automatically populated for credit card tips - cash tips are not included)
# 13                                                                                                                                                                                                                  Total amount of all tolls paid in trip
# 14                                                                                                                                                                                   $0.30 improvement surcharge assessed on hailed trips at the flag drop
# 15                                                                                                                                                                                     The total amount charged to passengers (does not include cash tips)
# 16                                                                                                           A numeric code signifying how the passenger paid for the trip (1= Credit card; 2= Cash; 3= No charge; 4= Dispute; 5= Unknown; 6= Voided trip)
# 17                                                       A code indicating whether the trip was a street-hail or a dispatch that is automatically assigned based on the metered rate in use but can be altered by the driver (1= Street-hail; 2= Dispatch)
# 18                                           Congestion surcharge for trips that start, end or pass through the congestion zone in Manhattan, south of 96th street ($2.50 for non-shared trips in Yellow Taxis; $2.75 for non-shared trips in Green Taxis)

# %%
# Loading taxi zones to check what's included
taxi_zones = pd.read_csv('taxi_zones.csv')

# Viewing taxi_zones
taxi_zones
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %% [markdown]
# taxi_zones contains location details. This will be useful when we want to expand the main dataframe to include location details.

# %%
# Checking if there are any duplicate rows before merging. No duplicate rows if False
taxi_zones['LocationID'].duplicated().any()
# Out:
# False

# %%
# Checking info
taxi_zones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LocationID    265 non-null    int64
#  1   Borough       265 non-null    object
#  2   Zone          264 non-null    object
#  3   service_zone  263 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.4+ KB

# %% [markdown]
# There are two null values in service_zone and one null value in Zone which is visible at the bottom end of the taxi_zones dataframe.

# %%
# Filling null values with Unknown
taxi_zones.fillna('Unknown', inplace = True)

# %%
# Loading taxi trips for all four years
taxi_trips_2017 = pd.read_csv('taxi_trips/2017_taxi_trips.csv')
taxi_trips_2018 = pd.read_csv('taxi_trips/2018_taxi_trips.csv')
taxi_trips_2019 = pd.read_csv('taxi_trips/2019_taxi_trips.csv')
taxi_trips_2020 = pd.read_csv('taxi_trips/2020_taxi_trips.csv')

# Printing the shape of each dataframe
print(taxi_trips_2017.shape)
print(taxi_trips_2018.shape)
print(taxi_trips_2019.shape)
print(taxi_trips_2020.shape)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (11740667, 18)
# (8807303, 18)
# (6044050, 19)
# (1734051, 19)

# %%
# Checking the info of dataframes
print(taxi_trips_2017.info())
print(taxi_trips_2018.info())
print(taxi_trips_2019.info())
print(taxi_trips_2020.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11740667 entries, 0 to 11740666
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             int64
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        int64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           int64
#  17  trip_type              float64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 1.6+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807303 entries, 0 to 8807302
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             int64
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        int64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           int64
#  17  trip_type              float64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 1.2+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6044050 entries, 0 to 6044049
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               float64
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             float64
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        float64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           float64
#  17  trip_type              float64
#  18  congestion_surcharge   float64
# dtypes: float64(14), int64(2), object(3)
# memory usage: 876.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1734051 entries, 0 to 1734050
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               float64
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             float64
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        float64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           float64
#  17  trip_type              float64
#  18  congestion_surcharge   float64
# dtypes: float64(14), int64(2), object(3)
# memory usage: 251.4+ MB
# None

# %% [markdown]
# congestion_surcharge is missing from taxi_trips_2017 and taxi_trips_2018.

# %%
# Adding the column to make all dataframes same width before concatenating the dataframes
taxi_trips_2017['congestion_surcharge'] = 0.0
taxi_trips_2018['congestion_surcharge'] = 0.0

# Checking the shape to confirm we have 19 columns
print(taxi_trips_2017.shape)
print(taxi_trips_2018.shape)
# Out:
# (11740667, 19)
# (8807303, 19)

# %%
# Concating all taxi trips
taxi_trips = pd.concat([taxi_trips_2017, taxi_trips_2018, taxi_trips_2019, taxi_trips_2020]).reset_index(drop = True)

# Checking the shape
taxi_trips.shape
# Out:
# (28326071, 19)

# %%
# Verifying the number of rows are as expected
print("Total rows in concatenated dataframe: {}".format(taxi_trips.shape[0]))
print("Rows in each dataframe added up: {}".format(taxi_trips_2017.shape[0] + taxi_trips_2018.shape[0] + taxi_trips_2019.shape[0] + taxi_trips_2020.shape[0]))
# Out:
# Total rows in concatenated dataframe: 28326071
# Rows in each dataframe added up: 28326071

# %% [markdown]
# # Data Types

# %%
# Checking the info of our concatenated dataframe
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28326071 entries, 0 to 28326070
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               float64
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             float64
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        float64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           float64
#  17  trip_type              float64
#  18  congestion_surcharge   float64
# dtypes: float64(14), int64(2), object(3)
# memory usage: 4.0+ GB

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h4>Data Types Inferred from Data Dictionary</h4><br>
#     <b>VendorID:</b> Integer<br>
#     <b>lpep_pickup_datetime:</b> DateTime<br>
#     <b>lpep_dropoff_datetime:</b> DateTime<br>
#     <b>store_and_fwd_flag:</b> String<br>
#     <b>RatecodeID:</b> Integer<br>
#     <b>PULocationID:</b> Integer<br>
#     <b>DOLocationID:</b> Integer<br>
#     <b>passenger_count:</b> Integer<br>
#     <b>trip_distance:</b> Float<br>
#     <b>fare_amount:</b> Float<br>
#     <b>extra:</b> Float<br>
#     <b>mta_tax:</b> Float<br>
#     <b>tip_amount:</b> Float<br>
#     <b>tolls_amount:</b> Float<br>
#     <b>improvement_surcharge:</b> Float<br>
#     <b>total_amount:</b> Float<br>
#     <b>payment_type:</b> Integer<br>
#     <b>trip_type:</b> Integer<br>
#     <b>congestion_surcharge:</b> Float<br>
# </div>

# %% [markdown]
# ###### Converting String to DateTime format

# %%
taxi_trips['lpep_pickup_datetime'] = pd.to_datetime(taxi_trips['lpep_pickup_datetime'])
taxi_trips['lpep_dropoff_datetime'] = pd.to_datetime(taxi_trips['lpep_dropoff_datetime'])

print(taxi_trips['lpep_pickup_datetime'].dtype)
print(taxi_trips['lpep_dropoff_datetime'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %% [markdown]
# ###### Converting Float to Integer

# %%
# Checking values in columns that are float to see if the values are actually integers
print(taxi_trips['VendorID'].value_counts())
print(taxi_trips['RatecodeID'].value_counts())
print(taxi_trips['passenger_count'].value_counts())
print(taxi_trips['payment_type'].value_counts())
print(taxi_trips['trip_type'].value_counts())
# Out:
# 2.0    22569744
# 1.0     4814128
# Name: VendorID, dtype: int64
# 1.0     26555346
# 5.0       740222
# 2.0        55534
# 4.0        18498
# 3.0        13769
# 6.0          349
# 99.0         154
# Name: RatecodeID, dtype: int64
# 1.0    23244224
# 2.0     2117741
# 5.0      909801
# 6.0      468953
# 3.0      455954
# 4.0      156794
# 0.0       29101
# 8.0         596
# 7.0         538
# 9.0         170
# Name: passenger_count, dtype: int64
# 1.0    14793538
# 2.0    12392982
# 3.0      132220
# 4.0       63966
# 5.0        1166
# Name: payment_type, dtype: int64
# 1.0    26640078
# 2.0      743340
# Name: trip_type, dtype: int64

# %%
# Converting to integer
taxi_trips['VendorID'] = taxi_trips['VendorID'].fillna(0.0).astype(int)
taxi_trips['RatecodeID'] = taxi_trips['RatecodeID'].fillna(0.0).astype(int)
taxi_trips['passenger_count'] = taxi_trips['passenger_count'].fillna(0.0).astype(int)
taxi_trips['payment_type'] = taxi_trips['payment_type'].fillna(0.0).astype(int)
taxi_trips['trip_type'] = taxi_trips['trip_type'].fillna(0.0).astype(int)

# %% [markdown]
# # Mapping and Exploring the columns

# %% [markdown]
# In this section, we are going to explore all the columns to see what needs further investigation whilst mapping and merging columns.

# %%
# Checking for null values in the dataframe
taxi_trips.isnull().sum()
# Out:
# VendorID                       0
# lpep_pickup_datetime           0
# lpep_dropoff_datetime          0
# store_and_fwd_flag        942199
# RatecodeID                     0
# PULocationID                   0
# DOLocationID                   0
# passenger_count                0
# trip_distance                  0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          2
# total_amount                   0
# payment_type                   0
# trip_type                      0
# congestion_surcharge     1488581
# dtype: int64

# %% [markdown]
# ### VendorID

# %% [markdown]
# A code indicating the LPEP provider that provided the record (1= Creative Mobile Technologies, LLC; 2= Verifone Inc.)

# %%
# Checking the value counts
taxi_trips['VendorID'].value_counts()
# Out:
# 2    22569744
# 1     4814128
# 0      942199
# Name: VendorID, dtype: int64

# %%
# Mapping the VendorID to the vendor
taxi_trips['Vendor'] = taxi_trips['VendorID'].map({1 : 'Creative Mobile Technologies, LLC', 2 : 'Verifone Inc.', 0 : 'Unknown'})

taxi_trips['Vendor'].value_counts()
# Out:
# Verifone Inc.                        22569744
# Creative Mobile Technologies, LLC     4814128
# Unknown                                942199
# Name: Vendor, dtype: int64

# %% [markdown]
# There are 942199 records where the VendorID is not provided. We will look at the possibility of populating the names of unknowns vendor in the next section.

# %% [markdown]
# ### lpep_pickup_datetime

# %% [markdown]
# The date and time when the meter was engaged

# %% [markdown]
# ### lpep_dropoff_datetime

# %% [markdown]
# The date and time when the meter was disengaged

# %% [markdown]
# ### store_and_fwd_flag

# %% [markdown]
# This flag indicates whether the trip record was held in vehicle memory before sending to the vendor, aka “store and forward,” because the vehicle did not have a connection to the server (Y= store and forward trip; N= not a store and forward trip)

# %%
# Checking the value counts
taxi_trips['store_and_fwd_flag'].value_counts()
# Out:
# N    27330950
# Y       52922
# Name: store_and_fwd_flag, dtype: int64

# %%
# Checking values in store_and_fwd_flag
print(taxi_trips['store_and_fwd_flag'].unique())
# Out:
# ['N' 'Y' nan]

# %%
# How many null values are there in store_and_fwd_flag?
print("There are {} null values in store_and_fwd_flag".format(taxi_trips['store_and_fwd_flag'].isnull().sum()))
# Out:
# There are 942199 null values in store_and_fwd_flag

# %% [markdown]
# We will look at the possibility of populating the null values in store_and_fwd_flag in the next section.

# %% [markdown]
# ### RatecodeID

# %% [markdown]
# The final rate code in effect at the end of the trip (1= Standard rate; 2= JFK; 3= Newark; 4= Nassau or Westchester; 5= Negotiated fare; 6= Group ride)

# %%
# Checking the value counts
taxi_trips['RatecodeID'].value_counts()
# Out:
# 1     26555346
# 0       942199
# 5       740222
# 2        55534
# 4        18498
# 3        13769
# 6          349
# 99         154
# Name: RatecodeID, dtype: int64

# %%
# Checking values in VendorID
print(taxi_trips['RatecodeID'].unique())
# Out:
# [ 1  2  4  3  6 99  5  0]

# %%
# Dictionary of ID and name
rate_codes = {1 : 'Standard rate', 2 : 'JFK', 3 : 'Newark', 4 : 'Nassau or Westchester', 5 : 'Negotiated fare', 6 : 'Group ride', 0 : 'Unknown', 99 : 'Unknown'}

# Mapping the RatecodeID to the rate code
taxi_trips['Ratecode'] = taxi_trips['RatecodeID'].map(rate_codes)

# Checking values in Ratecode
taxi_trips['Ratecode'].value_counts()
# Out:
# Standard rate            26555346
# Unknown                    942353
# Negotiated fare            740222
# JFK                         55534
# Nassau or Westchester       18498
# Newark                      13769
# Group ride                    349
# Name: Ratecode, dtype: int64

# %%
# How many null values are there in Ratecode?
print("There are {} unknowns in Ratecode".format(taxi_trips.loc[taxi_trips['Ratecode']=='Unknown'].shape[0]))
# Out:
# There are 942353 unknowns in Ratecode

# %% [markdown]
# We will look at the possibility of populating the unknowns in Ratecode in the next section.

# %% [markdown]
# ### PULocationID

# %% [markdown]
# TLC Taxi Zone in which the taximeter was engaged

# %%
# Checking the value counts
taxi_trips['PULocationID'].value_counts()
# Out:
# 74     1894141
# 75     1629516
# 41     1587500
# 7      1300642
# 82     1208719
#         ...
# 204         40
# 12          33
# 99          19
# 199         15
# 105          1
# Name: PULocationID, Length: 262, dtype: int64

# %%
# How many null values are there in PULocationID?
print("There are {} null values in PULocationID".format(taxi_trips['PULocationID'].isnull().sum()))
# Out:
# There are 0 null values in PULocationID

# %%
# Checking the lowest and highest numbers in PULocationID
print(taxi_trips['PULocationID'].min())
print(taxi_trips['PULocationID'].max())
# Out:
# 1
# 265

# %%
# Merge PULocationID with taxi_zones
taxi_trips = taxi_trips.merge(right=taxi_zones, how='left', left_on='PULocationID', right_on='LocationID')

# %%
# Dropping LocationID from taxi_trips that was merged from taxi_zones
taxi_trips.drop(columns='LocationID', inplace=True)

# %%
# Renaming merged columns
taxi_trips.rename(columns={'Borough' : 'PU_Borough', 'Zone' : 'PU_Zone', 'service_zone' : 'PU_service_zone'}, inplace=True)

# %% [markdown]
# ### DOLocationID

# %% [markdown]
# TLC Taxi Zone in which the taximeter was disengaged

# %%
# Checking the value counts
taxi_trips['DOLocationID'].value_counts()
# Out:
# 74     996733
# 42     963534
# 41     858422
# 7      817099
# 129    751496
#         ...
# 2         165
# 99         45
# 199        13
# 105         8
# 110         1
# Name: DOLocationID, Length: 263, dtype: int64

# %%
# How many null values are there in DOLocationID?
print("There are {} null values in DOLocationID".format(taxi_trips['DOLocationID'].isnull().sum()))
# Out:
# There are 0 null values in DOLocationID

# %%
# Checking the lowest and highest numbers in DOLocationID
print(taxi_trips['DOLocationID'].min())
print(taxi_trips['DOLocationID'].max())
# Out:
# 1
# 265

# %%
# Merge DOLocationID with taxi_zones
taxi_trips = taxi_trips.merge(right=taxi_zones, how='left', left_on='DOLocationID', right_on='LocationID')

# %%
# Dropping LocationID from taxi_trips that was merged from taxi_zones
taxi_trips.drop(columns='LocationID', inplace=True)

# %%
# Renaming merged columns
taxi_trips.rename(columns={'Borough' : 'DO_Borough', 'Zone' : 'DO_Zone', 'service_zone' : 'DO_service_zone'}, inplace=True)

# %% [markdown]
# ### passenger_count

# %% [markdown]
# The number of passengers in the vehicle (this is a driver entered value)

# %%
# Checking the value counts
taxi_trips['passenger_count'].value_counts()
# Out:
# 1    23244224
# 2     2117741
# 0      971300
# 5      909801
# 6      468953
# 3      455954
# 4      156794
# 8         596
# 7         538
# 9         170
# Name: passenger_count, dtype: int64

# %%
# Printing the number of missing passenger_count
print("There are {} records with missing passenger_count".format(taxi_trips.loc[taxi_trips['passenger_count']==0].shape[0]))
# Out:
# There are 971300 records with missing passenger_count

# %% [markdown]
# We will look at the possibility of populating the 0s in passenger_count in the next section.

# %% [markdown]
# ### trip_distance

# %% [markdown]
# The elapsed trip distance in miles reported by the taximeter

# %%
# Checking the value counts
taxi_trips['trip_distance'].value_counts()
# Out:
#  0.00     438914
#  0.90     295293
#  1.00     292823
#  0.80     289703
#  1.10     276241
#            ...
# -23.85         1
#  52.57         1
#  65.32         1
#  74.03         1
#  36.83         1
# Name: trip_distance, Length: 8314, dtype: int64

# %%
# Checking the column description
taxi_trips['trip_distance'].describe()
# Out:
# count    2.832607e+07
# mean     3.866140e+00
# std      2.969125e+02
# min     -2.032908e+04
# 25%      1.030000e+00
# 50%      1.860000e+00
# 75%      3.660000e+00
# max      2.056541e+05
# Name: trip_distance, dtype: float64

# %% [markdown]
# Minimum value of trip_distance is in the negative. Let's investigate the negatives

# %%
# How many rows are there where the trip_distance is in the negative?
print('There are {} records where the trip_distance is in the negative'.format(taxi_trips.loc[taxi_trips['trip_distance']<0].shape[0]))
# Out:
# There are 19487 records where the trip_distance is in the negative

# %%
# Checking the first 10 rows where the trip_distance is in the negative.
taxi_trips.loc[taxi_trips['trip_distance']<0].head(10)
# Out:
#           VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 21880092         2  2019-11-20 16:02:33   2019-11-20 16:23:41
# 21880097         2  2019-11-21 17:39:56   2019-11-21 18:07:10
# 21880102         2  2019-11-23 08:25:54   2019-11-23 08:41:05
# 21880105         2  2019-11-24 08:17:53   2019-11-24 08:41:19
# 21880109         2  2019-11-25 08:27:44   2019-11-25 08:43:54
# 21880110         2  2019-11-25 09:46:59   2019-11-25 10:55:47
# 21880113         2  2019-11-25 12:31:15   2019-11-25 14:13:59
# 21880114         2  2019-11-25 12:08:28   2019-11-25 14:51:40
# 21880115         2  2019-11-25 19:09:26   2019-11-25 19:57:56
# 21880175         2  2019-12-08 13:40:04   2019-12-08 14:01:43
#
#          store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 21880092                  N           5           197           124
# 21880097                  N           5            65           225
# 21880102                  N           5            92             9
# 21880105                  N           5           188           225
# 21880109                  N           5           177            35
# 21880110                  N           5            35            48
# 21880113                  N           5           217            48
# 21880114                  N           5            91           108
# 21880115                  N           5            33            76
# 21880175                  N           5           124            76
#
#           passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 21880092                1          -4.46        14.96    0.0      0.5
# 21880097                1          -3.87        23.51    0.0      0.5
# 21880102                1          -5.28        18.95    0.0      0.5
# 21880105                1          -4.33        13.92    0.0      0.5
# 21880109                1          -1.43        18.92    0.0      0.5
# 21880110                1         -12.95        40.10    0.0      0.5
# 21880113                1          -3.46        12.35    0.0      0.5
# 21880114                1          -1.80         7.20    0.0      0.5
# 21880115                1          -7.55        21.09    0.0      0.5
# 21880175                1          -3.93         9.00    0.0      0.5
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 21880092         0.0           0.0                    0.3         15.76
# 21880097         0.0           0.0                    0.3         24.31
# 21880102         0.0           0.0                    0.3         19.75
# 21880105         0.0           0.0                    0.3         14.72
# 21880109         0.0           0.0                    0.3         19.72
# 21880110         0.0           0.0                    0.3         40.90
# 21880113         0.0           0.0                    0.3         13.15
# 21880114         0.0           0.0                    0.3          8.00
# 21880115         0.0           0.0                    0.3         21.89
# 21880175         0.0           0.0                    0.3          9.80
#
#           payment_type  trip_type  congestion_surcharge         Vendor  \
# 21880092             2          1                   0.0  Verifone Inc.
# 21880097             2          1                   0.0  Verifone Inc.
# 21880102             2          1                   0.0  Verifone Inc.
# 21880105             2          1                   0.0  Verifone Inc.
# 21880109             2          1                   0.0  Verifone Inc.
# 21880110             2          1                   0.0  Verifone Inc.
# 21880113             2          1                   0.0  Verifone Inc.
# 21880114             2          1                   0.0  Verifone Inc.
# 21880115             2          1                   0.0  Verifone Inc.
# 21880175             2          1                   0.0  Verifone Inc.
#
#                  Ratecode PU_Borough                      PU_Zone  \
# 21880092  Negotiated fare     Queens                Richmond Hill
# 21880097  Negotiated fare   Brooklyn  Downtown Brooklyn/MetroTech
# 21880102  Negotiated fare     Queens                     Flushing
# 21880105  Negotiated fare   Brooklyn    Prospect-Lefferts Gardens
# 21880109  Negotiated fare   Brooklyn                   Ocean Hill
# 21880110  Negotiated fare   Brooklyn                  Brownsville
# 21880113  Negotiated fare   Brooklyn           South Williamsburg
# 21880114  Negotiated fare   Brooklyn                    Flatlands
# 21880115  Negotiated fare   Brooklyn             Brooklyn Heights
# 21880175  Negotiated fare     Queens                 Howard Beach
#
#          PU_service_zone DO_Borough             DO_Zone DO_service_zone
# 21880092       Boro Zone     Queens        Howard Beach       Boro Zone
# 21880097       Boro Zone   Brooklyn  Stuyvesant Heights       Boro Zone
# 21880102       Boro Zone     Queens          Auburndale       Boro Zone
# 21880105       Boro Zone   Brooklyn  Stuyvesant Heights       Boro Zone
# 21880109       Boro Zone   Brooklyn         Brownsville       Boro Zone
# 21880110       Boro Zone  Manhattan        Clinton East     Yellow Zone
# 21880113       Boro Zone  Manhattan        Clinton East     Yellow Zone
# 21880114       Boro Zone   Brooklyn           Gravesend       Boro Zone
# 21880115       Boro Zone   Brooklyn       East New York       Boro Zone
# 21880175       Boro Zone   Brooklyn       East New York       Boro Zone

# %% [markdown]
# These are valid records and looks like the minus is displayed in error

# %%
# Sum of trip_distance as it is
sum_trip_distance = taxi_trips['trip_distance'].sum()

# Sum of positive values in trip_distance
sum_trip_distance_positive = taxi_trips.loc[taxi_trips['trip_distance']>0,'trip_distance'].sum()

# Sum of negative values in trip_distance
sum_trip_distance_negative = taxi_trips.loc[taxi_trips['trip_distance']<0,'trip_distance'].sum()

# Expected sum of trip_distance when the negative values are converted to positive values
sum_trip_distance_exp_converted = taxi_trips.loc[taxi_trips['trip_distance']>0,'trip_distance'].sum() + taxi_trips.loc[taxi_trips['trip_distance']<0,'trip_distance'].abs().sum()

print('Sum of trip_distance: {:.2f}'.format(sum_trip_distance))
print('Sum of positive values in trip_distance: {:.2f}'.format(sum_trip_distance_positive))
print('Sum of negative values in trip_distance: {:.2f}'.format(sum_trip_distance_negative))
print('Expected sum after converting negative values to positive: {:.2f}'.format(sum_trip_distance_exp_converted))
# Out:
# Sum of trip_distance: 109512570.19
# Sum of positive values in trip_distance: 109715069.74
# Sum of negative values in trip_distance: -202499.55
# Expected sum after converting negative values to positive: 109917569.29

# %%
# Reassigning the column with it's absolute value
taxi_trips['trip_distance'] = taxi_trips['trip_distance'].abs()

# Checking if the sum matches with the expected sum in the previous step
print('Actual sum of trip_distance after converting negative values to positive: {:.2f}'.format(taxi_trips['trip_distance'].sum()))
# Out:
# Actual sum of trip_distance after converting negative values to positive: 109917569.29

# %%
# Checking the column description
taxi_trips['trip_distance'].describe()
# Out:
# count    2.832607e+07
# mean     3.880438e+00
# std      2.969123e+02
# min      0.000000e+00
# 25%      1.030000e+00
# 50%      1.870000e+00
# 75%      3.660000e+00
# max      2.056541e+05
# Name: trip_distance, dtype: float64

# %% [markdown]
# Minimum value of trip_distance is now zero. Why are there zeros?

# %%
# How many rows are there where the trip_distance is zero?
print('There are {} records where the trip_distance is zero'.format(taxi_trips.loc[taxi_trips['trip_distance']==0].shape[0]))
# Out:
# There are 438914 records where the trip_distance is zero

# %% [markdown]
# Possible explanation of zero trip_distance:
#  - Ride was less than 0.1 miles. This can be identified if the minimum fare is provided
#  - Driver forgot to engage the meter.
#
# We will look at the possibility of populating the 0s in trip_distance in the next section.

# %% [markdown]
# ### fare_amount

# %% [markdown]
# The time-and-distance fare calculated by the meter

# %%
# Checking the column description
taxi_trips['fare_amount'].describe()
# Out:
# count    2.832607e+07
# mean     1.318245e+01
# std      1.187243e+01
# min     -8.900000e+02
# 25%      6.500000e+00
# 50%      9.500000e+00
# 75%      1.600000e+01
# max      1.044584e+04
# Name: fare_amount, dtype: float64

# %%
# Reassigning the column with it's absolute value
taxi_trips['fare_amount'] = taxi_trips['fare_amount'].abs()

# %%
# Checking the column description
taxi_trips['fare_amount'].describe()
# Out:
# count    2.832607e+07
# mean     1.321725e+01
# std      1.183367e+01
# min      0.000000e+00
# 25%      6.500000e+00
# 50%      9.500000e+00
# 75%      1.600000e+01
# max      1.044584e+04
# Name: fare_amount, dtype: float64

# %%
# How many rows are there where the fare_amount is zero?
fare_amount_zero = taxi_trips.loc[taxi_trips['fare_amount']==0].shape[0]

print('There are {} records where the fare_amount is zero'.format(fare_amount_zero))
# Out:
# There are 59225 records where the fare_amount is zero

# %% [markdown]
# We will look at the possibility of populating the 0s in fare_amount in the next section. From running describe(), we can see that the maximum fare_amount is 10445.84. This seems highly unlikely and we will investigate values like this in the next section.

# %% [markdown]
# ### extra

# %% [markdown]
# Miscellaneous extras and surcharges (this only includes the 0.50 and 1.00 rush hour and overnight charges)

# %%
# Checking the column description
taxi_trips['extra'].describe()
# Out:
# count    2.832607e+07
# mean     3.957281e-01
# std      5.724350e-01
# min     -2.542000e+01
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      5.000000e-01
# max      3.000000e+01
# Name: extra, dtype: float64

# %%
# Reassigning the column with it's absolute value
taxi_trips['extra'] = taxi_trips['extra'].abs()

# %%
# Checking the value counts
taxi_trips['extra'].value_counts()
# Out:
# 0.00    14389099
# 0.50     8158890
# 1.00     5066194
# 2.75      605657
# 3.25       35476
#           ...
# 1.46           1
# 2.20           1
# 3.66           1
# 1.71           1
# 0.83           1
# Name: extra, Length: 105, dtype: int64

# %% [markdown]
# surcharges only includes the charges of 0.50 and 1.00 but it's possible to have other values as the Miscellaneous extras could be anything other than negatives. 0s are fine for this column.

# %% [markdown]
# ### mta_tax

# %% [markdown]
# $0.50 MTA tax that is automatically triggered based on the metered rate in use

# %%
taxi_trips['mta_tax'].describe()
# Out:
# count    2.832607e+07
# mean     4.785649e-01
# std      1.085238e-01
# min     -5.000000e-01
# 25%      5.000000e-01
# 50%      5.000000e-01
# 75%      5.000000e-01
# max      8.291000e+01
# Name: mta_tax, dtype: float64

# %%
# Reassigning the column with it's absolute value
taxi_trips['mta_tax'] = taxi_trips['mta_tax'].abs()

# %%
taxi_trips['mta_tax'].value_counts()
# Out:
# 0.50     27250099
# 0.00      1075875
# 3.55           42
# 0.08            7
# 0.60            7
# 0.11            6
# 0.55            5
# 0.07            5
# 0.25            5
# 0.09            2
# 0.12            1
# 17.33           1
# 0.13            1
# 0.36            1
# 1.37            1
# 0.10            1
# 0.65            1
# 1.00            1
# 82.91           1
# 4.41            1
# 0.81            1
# 2.75            1
# 26.22           1
# 0.32            1
# 0.18            1
# 3.80            1
# 1.50            1
# 0.83            1
# Name: mta_tax, dtype: int64

# %% [markdown]
# Only 0.00 and 0.50 are acceptable for this column. We will investigate other values in the next section.

# %% [markdown]
# ### tip_amount

# %% [markdown]
# Tip amount (automatically populated for credit card tips - cash tips are not included)

# %%
taxi_trips['tip_amount'].describe()
# Out:
# count    2.832607e+07
# mean     1.080043e+00
# std      2.094613e+00
# min     -1.010000e+02
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.860000e+00
# max      6.412000e+02
# Name: tip_amount, dtype: float64

# %%
# Reassigning the column with it's absolute value
taxi_trips['tip_amount'] = taxi_trips['tip_amount'].abs()

# %%
taxi_trips['tip_amount'].value_counts()
# Out:
# 0.00      17264828
# 1.00        812133
# 2.00        595508
# 2.75        289056
# 3.00        228955
#             ...
# 94.29            1
# 46.92            1
# 30.83            1
# 32.17            1
# 224.57           1
# Name: tip_amount, Length: 4058, dtype: int64

# %% [markdown]
# tip_amount could be any number. However, from the above value counts, we can see that there's one tip amount of 224.57. This seems highly unlikely and we will investigate values like this in the next section.

# %% [markdown]
# ### tolls_amount

# %% [markdown]
# Total amount of all tolls paid in trip

# %%
taxi_trips['tolls_amount'].describe()
# Out:
# count    2.832607e+07
# mean     1.764550e-01
# std      1.988191e+00
# min     -8.000000e+01
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      7.999920e+03
# Name: tolls_amount, dtype: float64

# %%
# Reassigning the column with it's absolute value
taxi_trips['tolls_amount'] = taxi_trips['tolls_amount'].abs()

# %%
taxi_trips['tolls_amount'].value_counts()
# Out:
# 0.00     27499507
# 5.76       429773
# 6.12       238267
# 5.54        39120
# 2.64        27228
#            ...
# 6.69            1
# 56.20           1
# 11.42           1
# 4.03            1
# 3.20            1
# Name: tolls_amount, Length: 1329, dtype: int64

# %% [markdown]
# tolls_amount could be any number. However, from running describe(), we can see that the maximum tolls_amount is 7999.92. This seems highly unlikely and we will investigate values like this in the next section.

# %% [markdown]
# ### improvement_surcharge

# %% [markdown]
# $0.30 improvement surcharge assessed on hailed trips at the flag drop

# %%
taxi_trips['improvement_surcharge'].describe()
# Out:
# count    2.832607e+07
# mean     2.869971e-01
# std      6.460169e-02
# min     -3.000000e-01
# 25%      3.000000e-01
# 50%      3.000000e-01
# 75%      3.000000e-01
# max      4.700000e-01
# Name: improvement_surcharge, dtype: float64

# %%
# Reassigning the column with it's absolute value
taxi_trips['improvement_surcharge'] = taxi_trips['improvement_surcharge'].abs()

# %%
taxi_trips['improvement_surcharge'].value_counts()
# Out:
# 0.30    27237306
# 0.00     1088751
# 0.43           3
# 0.11           2
# 0.12           1
# 0.46           1
# 0.32           1
# 0.44           1
# 0.47           1
# 0.17           1
# 0.13           1
# Name: improvement_surcharge, dtype: int64

# %%
# Checking the number of null values
taxi_trips['improvement_surcharge'].isnull().sum()
# Out:
# 2

# %%
# Filling the null values with 0.0
taxi_trips['improvement_surcharge'].fillna(value=0.0, inplace=True)

# %% [markdown]
# Only 0.0 and 0.3 are acceptable for improvement_surcharge. We will investigate other values in the next section.

# %% [markdown]
# ### total_amount

# %% [markdown]
# The total amount charged to passengers (does not include cash tips)

# %%
taxi_trips['total_amount'].describe()
# Out:
# count    2.832607e+07
# mean     1.571784e+01
# std      1.321935e+01
# min     -8.903000e+02
# 25%      8.300000e+00
# 50%      1.180000e+01
# 75%      1.880000e+01
# max      1.052875e+04
# Name: total_amount, dtype: float64

# %%
# Reassigning the column with it's absolute value
taxi_trips['total_amount'] = taxi_trips['total_amount'].abs()

# %%
# How many rows are there where the total_amount is zero?
total_amount_zero = taxi_trips.loc[taxi_trips['total_amount']==0].shape[0]

print('There are {} records where the total_amount is zero'.format(total_amount_zero))
# Out:
# There are 56972 records where the total_amount is zero

# %% [markdown]
# We will look at the possibility of populating the 0s in total_amount in the next section.

# %% [markdown]
# ### payment_type

# %% [markdown]
# A numeric code signifying how the passenger paid for the trip (1= Credit card; 2= Cash; 3= No charge; 4= Dispute; 5= Unknown; 6= Voided trip)

# %%
# Checking values in payment_type
taxi_trips['payment_type'].value_counts()
# Out:
# 1    14793538
# 2    12392982
# 0      942199
# 3      132220
# 4       63966
# 5        1166
# Name: payment_type, dtype: int64

# %%
# Dictionary of code and name
payment_types = {1 : 'Credit card', 2 : 'Cash', 3 : 'No charge', 4 : 'Dispute', 5 : 'Unknown', 6 : 'Voided trip', 0 : 'Unknown'}

# Mapping the payment type
taxi_trips['payment_type'] = taxi_trips['payment_type'].map(payment_types)

taxi_trips['payment_type'].value_counts()
# Out:
# Credit card    14793538
# Cash           12392982
# Unknown          943365
# No charge        132220
# Dispute           63966
# Name: payment_type, dtype: int64

# %% [markdown]
# There are 943365 unknown payment_type. We will look at the possibility of populating them in the next section.

# %% [markdown]
# ### trip_type

# %% [markdown]
# A code indicating whether the trip was a street-hail or a dispatch that is automatically assigned based on the metered rate in use but can be altered by the driver (1= Street-hail; 2= Dispatch)

# %%
# Checking values in trip_type
taxi_trips['trip_type'].value_counts()
# Out:
# 1    26640078
# 0      942653
# 2      743340
# Name: trip_type, dtype: int64

# %%
trip_types = {1 : 'Street-hail', 2 : 'Dispatch', 0 : 'Unknown'}

taxi_trips['trip_type'] = taxi_trips['trip_type'].map(trip_types)

taxi_trips['trip_type'].value_counts()
# Out:
# Street-hail    26640078
# Unknown          942653
# Dispatch         743340
# Name: trip_type, dtype: int64

# %% [markdown]
# There are 942653 unknown trip_type. We will look at the possibility of populating them in the next section.

# %% [markdown]
# ### congestion_surcharge

# %% [markdown]
# Congestion surcharge for trips that start, end or pass through the congestion zone in Manhattan, south of 96th street (2.50 for non-shared trips in Yellow Taxis; 2.75 for non-shared trips in Green Taxis)

# %%
taxi_trips['congestion_surcharge'].describe()
# Out:
# count    2.683749e+07
# mean     9.726175e-02
# std      5.078660e-01
# min     -2.750000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.750000e+00
# Name: congestion_surcharge, dtype: float64

# %%
# Reassigning the column with it's absolute value
taxi_trips['congestion_surcharge'] = taxi_trips['congestion_surcharge'].abs()

# %%
taxi_trips['congestion_surcharge'].value_counts()
# Out:
# 0.00    25887588
# 2.75      944457
# 2.50        5361
# 0.75          81
# 2.00           2
# 0.30           1
# Name: congestion_surcharge, dtype: int64

# %%
# Checking the number of null values
taxi_trips['congestion_surcharge'].isnull().sum()
# Out:
# 1488581

# %%
# Filling the null values with 0.0
taxi_trips['congestion_surcharge'].fillna(value=0.0, inplace=True)

# %% [markdown]
# Only 0.00, 2.50, and 2.75 are valid for congestion_surcharge. We will investigate other values in the next section.

# %% [markdown]
# # Cleaning Unrecognised and Unknown Values

# %% [markdown]
# In this section, we will try to update unknown values and clean unrecognised values we came across in the previous section.

# %% [markdown]
# ### New column: total_amount_check

# %% [markdown]
# For checking purposes, we are going to create a new column named total_amount_check with the below formula:
# - total_amount = fare_amount + improvement_surcharge + tolls_amount + tip_amount + mta_tax + extra + congestion_surcharge

# %%
# Creating new column total_amount_check with the above formula
taxi_trips['total_amount_check'] = (taxi_trips['fare_amount'] + taxi_trips['improvement_surcharge'] + taxi_trips['tolls_amount'] + taxi_trips['tip_amount'] + taxi_trips['mta_tax'] + taxi_trips['extra'] + taxi_trips['congestion_surcharge']).round(2)

# %% [markdown]
# To check the validity of our formula, we need to see if the total_amount_check actually matches with total_amount.

# %%
# Creating a conditional column to see if the totals match
taxi_trips['total_amount_match?'] = np.where(taxi_trips['total_amount'] == taxi_trips['total_amount_check'], 'Match', 'No Match')

# %%
taxi_trips['total_amount_match?'].value_counts()
# Out:
# Match       27735546
# No Match      590525
# Name: total_amount_match?, dtype: int64

# %% [markdown]
# 97.9% of values in total_amount_check matches with total_amount. This shows the formula is correct and for the values that don't match, we will need to carry out further invetsigation.

# %%
# Creating a new column to hold the difference between total_amount and total_amount_check
taxi_trips['total_amount_difference'] = taxi_trips['total_amount'] - taxi_trips['total_amount_check']

# %% [markdown]
# ### New column: trip_duration_mins

# %% [markdown]
# Creating a new column to hold trip duration in minutes. This could especially be useful in updating the 0s in fare_amount whilst determining the validity of high values in fare_amount

# %%
taxi_trips['trip_duration_mins'] = (taxi_trips['lpep_dropoff_datetime'] - taxi_trips['lpep_pickup_datetime']) / np.timedelta64(1, 'm')

# %% [markdown]
# ### congestion_surcharge

# %% [markdown]
# Only 0.00, 2.50, and 2.75 are valid for congestion_surcharge. Others needs to be modified.

# %%
taxi_trips['congestion_surcharge'].value_counts()
# Out:
# 0.00    27376169
# 2.75      944457
# 2.50        5361
# 0.75          81
# 2.00           2
# 0.30           1
# Name: congestion_surcharge, dtype: int64

# %% [markdown]
# Let's check 0.3 first as it is only one record. It should be either 0.00, 2.50 or 2.75

# %%
# Rows where congestion_surcharge is 0.3
taxi_trips.loc[taxi_trips['congestion_surcharge']==0.3, ['fare_amount','extra','mta_tax','tip_amount','tolls_amount','improvement_surcharge','congestion_surcharge','total_amount','total_amount_check','total_amount_difference']]
# Out:
#           fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 21224506        161.0    0.0      0.5       32.35           0.0
#
#           improvement_surcharge  congestion_surcharge  total_amount  \
# 21224506                    0.3                   0.3        194.15
#
#           total_amount_check  total_amount_difference
# 21224506              194.45                     -0.3

# %% [markdown]
# From the above, we can conclude that the 0.3 congestion_surcharge is an error and should be 0.00 as the total_amount is 0.30 less than the total_amount_check

# %%
# Replacing 0.3 in congestion_surcharge with 0.00
taxi_trips.loc[taxi_trips['congestion_surcharge']==0.3, 'congestion_surcharge'] = 0.00

# %% [markdown]
# Now, let's check 2.0. It should be either 0.00, 2.50 or 2.75

# %%
# Rows where congestion_surcharge is 2.0 and total_amount_difference is 0.75
taxi_trips.loc[(taxi_trips['congestion_surcharge']==2.0) & (taxi_trips['total_amount_difference']==0.75), ['fare_amount','extra','mta_tax','tip_amount','tolls_amount','improvement_surcharge','congestion_surcharge','total_amount','total_amount_check','total_amount_difference']]
# Out:
#           fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 25940904          7.0    0.5      0.5         0.0           0.0
# 25940906          6.5    0.5      0.5         0.0           0.0
#
#           improvement_surcharge  congestion_surcharge  total_amount  \
# 25940904                    0.3                   2.0         11.05
# 25940906                    0.3                   2.0         10.55
#
#           total_amount_check  total_amount_difference
# 25940904                10.3                     0.75
# 25940906                 9.8                     0.75

# %% [markdown]
# From the above, we can conclude that the 2.0 congestion_surcharge is an error and should be 2.75 as the total_amount is 0.75 more than the total_amount_check

# %%
# Replacing 2.0 in congestion_surcharge with 2.75 where congestion_surcharge is 2.0 and total_amount_difference is 0.75
taxi_trips.loc[(taxi_trips['congestion_surcharge']==2.0) & (taxi_trips['total_amount_difference']==0.75), 'congestion_surcharge'] = 2.75

# %% [markdown]
# Now, let's check 0.75. It should be either 0.00, 2.50 or 2.75

# %%
# Rows where congestion_surcharge is 0.75 and total_amount_difference is 2.00
taxi_trips.loc[(taxi_trips['congestion_surcharge']==0.75) & ((taxi_trips['total_amount_difference']==2.00) | (taxi_trips['total_amount_difference']==1.75)), ['fare_amount','extra','mta_tax','tip_amount','tolls_amount','improvement_surcharge','congestion_surcharge','total_amount','total_amount_check','total_amount_difference']]
# Out:
# Empty DataFrame
# Columns: [fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, congestion_surcharge, total_amount, total_amount_check, total_amount_difference]
# Index: []

# %% [markdown]
# There are no records where the total_amount_difference is 2.00 or 1.75 when the congestion_surcharge is 0.75. This might be due to rounding. Let's check what values are in total_amount_difference when the congestion_surcharge is 0.75

# %%
# Checking the value counts of total_amount_difference when the congestion_surcharge is 0.75
taxi_trips.loc[taxi_trips['congestion_surcharge']==0.75, 'total_amount_difference'].value_counts()
# Out:
# 0.00    72
# 1.95     7
# 1.95     1
# 9.90     1
# Name: total_amount_difference, dtype: int64

# %% [markdown]
# There are 8 records where the total_amount_difference becomes 2 when rounded to 0 decimal place. We can update them as 2.75

# %%
# Replacing 0.75 in congestion_surcharge with 2.75 where total_amount_difference is 2.0
taxi_trips.loc[(taxi_trips['congestion_surcharge']==0.75) & (taxi_trips['total_amount_difference'].round(0)==2.00), 'congestion_surcharge'] = 2.75

# %% [markdown]
# We are low left with 73 records where congestion_surcharge is 0.75:
#  - total_amount_difference is 0 for 72 of those records. As this congestion_surcharge of 0.75 is included in the total_amount, we should keep this somewhere but not in congestion_surcharge as only 0.00, 2.50 and 2.75 are valid, and setting the congestion_surcharge to either 0, 2.50 or 2.75 would cause issues for the total_amount.
#  - total_amount_difference is 9.90 for 1 record. total_amount is off by 9.90 and updating congestion_surcharge as 2.75 will bring the difference down to 7.90
#
# We can move these amounts to another column that's more suitable.

# %%
taxi_trips['congestion_surcharge'].value_counts()
# Out:
# 0.00    27376170
# 2.75      944467
# 2.50        5361
# 0.75          73
# Name: congestion_surcharge, dtype: int64

# %%
# Checking the sums before updating the values

sum_congestion_surcharge = taxi_trips['congestion_surcharge'].sum()
sum_extra = taxi_trips['extra'].sum()
sum_values_to_move = taxi_trips.loc[taxi_trips['congestion_surcharge']==0.75, 'congestion_surcharge'].sum()
exp_sum_congestion_surcharge = taxi_trips['congestion_surcharge'].sum() - sum_values_to_move
exp_sum_extra = sum_extra + sum_values_to_move

print('Sum of congestion_surcharge: {:.2f}'.format(sum_congestion_surcharge))
print('Sum of extra: {:.2f}'.format(sum_extra))
print('Sum of values to be moved: {:.2f}'.format(sum_values_to_move))
print('Expected sum of congestion_surcharge after update: {:.2f}'.format(exp_sum_congestion_surcharge))
print('Expected sum of extra after update: {:.2f}'.format(exp_sum_extra))
# Out:
# Sum of congestion_surcharge: 2610741.50
# Sum of extra: 11259442.63
# Sum of values to be moved: 54.75
# Expected sum of congestion_surcharge after update: 2610686.75
# Expected sum of extra after update: 11259497.38

# %%
# Adding 0.75 values in congestion_surcharge to extra
taxi_trips.loc[taxi_trips['congestion_surcharge']==0.75, 'extra'] = taxi_trips['extra'] + taxi_trips['congestion_surcharge']

# Setting 0.75 values in congestion_surcharge as 0.00
taxi_trips.loc[taxi_trips['congestion_surcharge']==0.75, 'congestion_surcharge'] = 0.00

# %%
# Checking the sums after updating the values to see if they are as expected

sum_congestion_surcharge = taxi_trips['congestion_surcharge'].sum()
sum_extra = taxi_trips['extra'].sum()

print('Sum of congestion_surcharge: {:.2f}'.format(sum_congestion_surcharge))
print('Sum of extra: {:.2f}'.format(sum_extra))
# Out:
# Sum of congestion_surcharge: 2610686.75
# Sum of extra: 11259497.38

# %% [markdown]
# The sums matches with the expected sums.

# %%
# Checking the values in congestion_surcharge for confirmation
taxi_trips['congestion_surcharge'].value_counts()
# Out:
# 0.00    27376243
# 2.75      944467
# 2.50        5361
# Name: congestion_surcharge, dtype: int64

# %% [markdown]
# The congestion_surcharge column is now clean with values of 0.00, 2.50 and 2.75 only

# %% [markdown]
# ### improvement_surcharge

# %% [markdown]
# $0.30 improvement surcharge assessed on hailed trips at the flag drop

# %%
taxi_trips['improvement_surcharge'].value_counts()
# Out:
# 0.30    27237306
# 0.00     1088753
# 0.43           3
# 0.11           2
# 0.12           1
# 0.46           1
# 0.32           1
# 0.44           1
# 0.47           1
# 0.17           1
# 0.13           1
# Name: improvement_surcharge, dtype: int64

# %% [markdown]
# improvement_surcharge should either be 0.00 or 0.30. Let's investigate values that are not 0.00 or 0.30

# %%
# Checking the rows where the improvement_surcharge is not 0.30 or 0.00
taxi_trips.loc[~(taxi_trips['improvement_surcharge']==0.30) & ~(taxi_trips['improvement_surcharge']==0.00)]
# Out:
#           VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 18577533         2  2018-10-30 07:39:44   2018-10-30 07:39:46
# 18577534         2  2018-10-30 07:40:11   2018-10-30 07:40:23
# 22075459         2  2019-11-12 15:32:34   2019-11-12 15:33:24
# 22086638         2  2019-11-12 13:54:01   2019-11-12 13:54:51
# 22086640         2  2019-11-12 16:00:12   2019-11-12 16:01:52
# 22090530         2  2019-12-03 17:40:00   2019-12-03 17:40:28
# 22362775         2  2019-11-12 15:29:51   2019-11-12 15:31:42
# 22362776         2  2019-11-12 15:57:44   2019-11-12 15:59:44
# 23029537         2  2019-11-08 10:42:12   2019-11-08 14:30:21
# 23031493         2  2019-11-08 10:42:12   2019-11-08 14:34:55
# 23031494         2  2019-11-08 10:42:12   2019-11-08 14:34:25
# 23031495         2  2019-11-08 14:34:57   2019-11-08 14:35:13
#
#          store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 18577533                  N           1           265           265
# 18577534                  N           1           265           265
# 22075459                  N           1           265           265
# 22086638                  N           1           265           265
# 22086640                  N           1           265           265
# 22090530                  N           1           193           193
# 22362775                  N           1           265           265
# 22362776                  N           1           265           265
# 23029537                  N           1           265           264
# 23031493                  N           1           265           264
# 23031494                  N           1           265           264
# 23031495                  N           1           264           264
#
#           passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 18577533                1            0.0         3.50    0.0      0.0
# 18577534                1            0.0         3.50    0.0      0.0
# 22075459                2            0.0         3.73    0.0      0.0
# 22086638                1            0.0         3.50    0.0      0.0
# 22086640                1            0.0         3.96    0.0      0.0
# 22090530                1            0.0         3.50    2.0      0.0
# 22362775                1            0.0         4.42    0.0      0.0
# 22362776                1            0.0         4.19    0.0      0.0
# 23029537                1            0.0        84.90    0.0      0.0
# 23031493                4            0.0         3.50    0.0      0.0
# 23031494                3            0.0         4.88    0.0      0.0
# 23031495                3            0.0         3.50    0.0      0.0
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 18577533         0.0          0.00                   0.11          3.61
# 18577534         0.0          0.00                   0.11          3.61
# 22075459         0.0          0.00                   0.44          4.17
# 22086638         0.0          0.00                   0.43          3.93
# 22086640         0.0          0.00                   0.12          4.08
# 22090530         0.0          0.00                   0.17          5.67
# 22362775         0.0          0.28                   0.46          5.16
# 22362776         0.0          4.50                   0.13          8.82
# 23029537         0.0          0.00                   0.32         85.22
# 23031493         0.0          0.00                   0.43          3.93
# 23031494         0.0          0.00                   0.47          5.35
# 23031495         0.0          0.00                   0.43          3.93
#
#          payment_type    trip_type  congestion_surcharge         Vendor  \
# 18577533         Cash  Street-hail                   0.0  Verifone Inc.
# 18577534         Cash  Street-hail                   0.0  Verifone Inc.
# 22075459         Cash  Street-hail                   0.0  Verifone Inc.
# 22086638         Cash  Street-hail                   0.0  Verifone Inc.
# 22086640         Cash  Street-hail                   0.0  Verifone Inc.
# 22090530         Cash  Street-hail                   0.0  Verifone Inc.
# 22362775         Cash  Street-hail                   0.0  Verifone Inc.
# 22362776         Cash  Street-hail                   0.0  Verifone Inc.
# 23029537         Cash  Street-hail                   0.0  Verifone Inc.
# 23031493         Cash  Street-hail                   0.0  Verifone Inc.
# 23031494         Cash  Street-hail                   0.0  Verifone Inc.
# 23031495         Cash  Street-hail                   0.0  Verifone Inc.
#
#                Ratecode PU_Borough                  PU_Zone PU_service_zone  \
# 18577533  Standard rate    Unknown                  Unknown         Unknown
# 18577534  Standard rate    Unknown                  Unknown         Unknown
# 22075459  Standard rate    Unknown                  Unknown         Unknown
# 22086638  Standard rate    Unknown                  Unknown         Unknown
# 22086640  Standard rate    Unknown                  Unknown         Unknown
# 22090530  Standard rate     Queens  Queensbridge/Ravenswood       Boro Zone
# 22362775  Standard rate    Unknown                  Unknown         Unknown
# 22362776  Standard rate    Unknown                  Unknown         Unknown
# 23029537  Standard rate    Unknown                  Unknown         Unknown
# 23031493  Standard rate    Unknown                  Unknown         Unknown
# 23031494  Standard rate    Unknown                  Unknown         Unknown
# 23031495  Standard rate    Unknown                       NV         Unknown
#
#          DO_Borough                  DO_Zone DO_service_zone  \
# 18577533    Unknown                  Unknown         Unknown
# 18577534    Unknown                  Unknown         Unknown
# 22075459    Unknown                  Unknown         Unknown
# 22086638    Unknown                  Unknown         Unknown
# 22086640    Unknown                  Unknown         Unknown
# 22090530     Queens  Queensbridge/Ravenswood       Boro Zone
# 22362775    Unknown                  Unknown         Unknown
# 22362776    Unknown                  Unknown         Unknown
# 23029537    Unknown                       NV         Unknown
# 23031493    Unknown                       NV         Unknown
# 23031494    Unknown                       NV         Unknown
# 23031495    Unknown                       NV         Unknown
#
#           total_amount_check total_amount_match?  total_amount_difference  \
# 18577533                3.61               Match                      0.0
# 18577534                3.61               Match                      0.0
# 22075459                4.17               Match                      0.0
# 22086638                3.93               Match                      0.0
# 22086640                4.08               Match                      0.0
# 22090530                5.67               Match                      0.0
# 22362775                5.16               Match                      0.0
# 22362776                8.82               Match                      0.0
# 23029537               85.22               Match                      0.0
# 23031493                3.93               Match                      0.0
# 23031494                5.35               Match                      0.0
# 23031495                3.93               Match                      0.0
#
#           trip_duration_mins
# 18577533            0.033333
# 18577534            0.200000
# 22075459            0.833333
# 22086638            0.833333
# 22086640            1.666667
# 22090530            0.466667
# 22362775            1.850000
# 22362776            2.000000
# 23029537          228.150000
# 23031493          232.716667
# 23031494          232.216667
# 23031495            0.266667

# %%
# Checking if there's any link between improvement_surcharge and trip_type using pivot table
pd.pivot_table(taxi_trips, index='trip_type', columns='improvement_surcharge', values='lpep_pickup_datetime', aggfunc='count', fill_value=0, margins=True, margins_name='Total')
# Out:
# improvement_surcharge      0.0  0.11  0.12  0.13  0.17       0.3  0.32  0.43  \
# trip_type
# Dispatch                709701     0     0     0     0     33639     0     0
# Street-hail              30255     2     1     1     1  26609811     1     3
# Unknown                 348797     0     0     0     0    593856     0     0
# Total                  1088753     2     1     1     1  27237306     1     3
#
# improvement_surcharge  0.44  0.46  0.47     Total
# trip_type
# Dispatch                  0     0     0    743340
# Street-hail               1     1     1  26640078
# Unknown                   0     0     0    942653
# Total                     1     1     1  28326071

# %%
# Checking if there's any link between improvement_surcharge and Ratecode using pivot table
pd.pivot_table(taxi_trips, index='Ratecode', columns='improvement_surcharge', values='lpep_pickup_datetime', aggfunc='count', fill_value=0, margins=True, margins_name='Total')
# Out:
# improvement_surcharge      0.0  0.11  0.12  0.13  0.17       0.3  0.32  0.43  \
# Ratecode
# Group ride                   4     0     0     0     0       345     0     0
# JFK                        421     0     0     0     0     55113     0     0
# Nassau or Westchester      274     0     0     0     0     18224     0     0
# Negotiated fare         687459     0     0     0     0     52763     0     0
# Newark                      97     0     0     0     0     13672     0     0
# Standard rate            51654     2     1     1     1  26503680     1     3
# Unknown                 348844     0     0     0     0    593509     0     0
# Total                  1088753     2     1     1     1  27237306     1     3
#
# improvement_surcharge  0.44  0.46  0.47     Total
# Ratecode
# Group ride                0     0     0       349
# JFK                       0     0     0     55534
# Nassau or Westchester     0     0     0     18498
# Negotiated fare           0     0     0    740222
# Newark                    0     0     0     13769
# Standard rate             1     1     1  26555346
# Unknown                   0     0     0    942353
# Total                     1     1     1  28326071

# %%
# Checking if there's any link between improvement_surcharge and payment_type using pivot table
pd.pivot_table(taxi_trips, index='payment_type', columns='improvement_surcharge', values='lpep_pickup_datetime', aggfunc='count', fill_value=0, margins=True, margins_name='Total')
# Out:
# improvement_surcharge      0.0  0.11  0.12  0.13  0.17       0.3  0.32  0.43  \
# payment_type
# Cash                    288939     2     1     1     1  12104031     1     3
# Credit card             439141     0     0     0     0  14354397     0     0
# Dispute                   4232     0     0     0     0     59734     0     0
# No charge                 7509     0     0     0     0    124711     0     0
# Unknown                 348932     0     0     0     0    594433     0     0
# Total                  1088753     2     1     1     1  27237306     1     3
#
# improvement_surcharge  0.44  0.46  0.47     Total
# payment_type
# Cash                      1     1     1  12392982
# Credit card               0     0     0  14793538
# Dispute                   0     0     0     63966
# No charge                 0     0     0    132220
# Unknown                   0     0     0    943365
# Total                     1     1     1  28326071

# %% [markdown]
# From above tables, the reason for having values other than 0.00 and 0.30 are not obvious. But all 12 occured with street-hail with standard rate where the payment_type is cash. From above pivot tables, the following are clear:
#  - 99.9% of street-hail	trips pays 0.30 improvement_surcharge
#  - 99.8% of standard rate trips pays 0.30 improvement_surcharge
#
# These charges are included in the total amount passengers are charged, which is confirmed by the total_amount_difference. Therefore, setting the improvement_surcharge to either 0 or 0.30 would cause issues for the total_amount.
#
# One option would be to move these amounts to another column that's more suitable. Two reasons for this are:
#  - Amount isn't 0.30. Therefore, this might not even be improvement_surcharge.
#  - It is included in the total_amount. Therefore, we need to keep it. Otherwise, the total_amount the passenger was charged wouldn't add up.
#
# Let's move the values other than 0.3 to extra as it seems the most suitable category.

# %%
# Checking the sums before updating the values

sum_improvement_surcharge = taxi_trips['improvement_surcharge'].sum()
sum_extra = taxi_trips['extra'].sum()
sum_values_to_move = taxi_trips.loc[~(taxi_trips['improvement_surcharge']==0.30) & ~(taxi_trips['improvement_surcharge']==0.00), 'improvement_surcharge'].sum()
exp_sum_improvement_surcharge = taxi_trips['improvement_surcharge'].sum() - sum_values_to_move
exp_sum_extra = sum_extra + sum_values_to_move

print('Sum of improvement_surcharge: {:.2f}'.format(sum_improvement_surcharge))
print('Sum of extra: {:.2f}'.format(sum_extra))
print('Sum of values to be moved: {:.2f}'.format(sum_values_to_move))
print('Expected sum of improvement_surcharge after update: {:.2f}'.format(exp_sum_improvement_surcharge))
print('Expected sum of extra after update: {:.2f}'.format(exp_sum_extra))
# Out:
# Sum of improvement_surcharge: 8171195.42
# Sum of extra: 11259497.38
# Sum of values to be moved: 3.62
# Expected sum of improvement_surcharge after update: 8171191.80
# Expected sum of extra after update: 11259501.00

# %%
# Adding values other than 0.3 to extra
taxi_trips.loc[~(taxi_trips['improvement_surcharge']==0.30) & ~(taxi_trips['improvement_surcharge']==0.00), 'extra'] = taxi_trips['extra'] + taxi_trips['improvement_surcharge']

# Setting values other than 0.3 as 0.00 in improvement_surcharge
taxi_trips.loc[~(taxi_trips['improvement_surcharge']==0.30) & ~(taxi_trips['improvement_surcharge']==0.00), 'improvement_surcharge'] = 0.00

# %%
# Checking the sums after updating the values to see if they are as expected

sum_improvement_surcharge = taxi_trips['improvement_surcharge'].sum()
sum_extra = taxi_trips['extra'].sum()

print('Sum of improvement_surcharge: {:.2f}'.format(sum_improvement_surcharge))
print('Sum of extra: {:.2f}'.format(sum_extra))
# Out:
# Sum of improvement_surcharge: 8171191.80
# Sum of extra: 11259501.00

# %% [markdown]
# The sums matches with the expected sums.

# %%
# Checking the values in improvement_surcharge for confirmation
taxi_trips['improvement_surcharge'].value_counts()
# Out:
# 0.3    27237306
# 0.0     1088765
# Name: improvement_surcharge, dtype: int64

# %% [markdown]
# The improvement_surcharge column is now clean with values of 0.0 and 0.3 only

# %% [markdown]
# ### mta_tax

# %% [markdown]
# $0.50 MTA tax that is automatically triggered based on the metered rate in use

# %%
taxi_trips['mta_tax'].value_counts()
# Out:
# 0.50     27250099
# 0.00      1075875
# 3.55           42
# 0.08            7
# 0.60            7
# 0.11            6
# 0.55            5
# 0.07            5
# 0.25            5
# 0.09            2
# 0.12            1
# 17.33           1
# 0.13            1
# 0.36            1
# 1.37            1
# 0.10            1
# 0.65            1
# 1.00            1
# 82.91           1
# 4.41            1
# 0.81            1
# 2.75            1
# 26.22           1
# 0.32            1
# 0.18            1
# 3.80            1
# 1.50            1
# 0.83            1
# Name: mta_tax, dtype: int64

# %% [markdown]
# Values in mta_tax should either be 0.00 or 0.50. Let's investigate values that are not 0.00 or 0.50

# %%
# Checking the rows where the mta_tax is not 0.50 or 0.00
taxi_trips.loc[~(taxi_trips['mta_tax']==0.50) & ~(taxi_trips['mta_tax']==0.00)]
# Out:
#           VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 492111           1  2017-01-12 15:29:58   2017-01-12 15:31:02
# 492112           1  2017-01-12 15:29:12   2017-01-12 15:29:30
# 492113           1  2017-01-12 15:27:28   2017-01-12 15:28:44
# 492485           1  2017-01-12 14:49:33   2017-01-12 14:52:09
# 493314           1  2017-01-12 14:52:46   2017-01-12 14:55:01
# ...            ...                  ...                   ...
# 27476246         1  2020-01-28 19:16:01   2020-01-28 19:16:07
# 27476247         1  2020-06-13 10:59:11   2020-06-13 11:04:10
# 27480831         1  2020-01-01 10:58:27   2020-01-01 10:58:27
# 27522650         1  2020-01-18 14:13:47   2020-01-18 14:13:49
# 28319946         2  2020-10-12 15:37:48   2020-10-12 15:38:36
#
#          store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 492111                    N           3           265           265
# 492112                    N           3           265           265
# 492113                    N           3           265           265
# 492485                    N           3           145           145
# 493314                    N           5           145           145
# ...                     ...         ...           ...           ...
# 27476246                  N           1           232           232
# 27476247                  N           1           236            75
# 27480831                  N           1           107           107
# 27522650                  N           1           263           263
# 28319946                  N           1           193           193
#
#           passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 492111                  1            0.0        20.50   0.50     0.60
# 492112                  1            0.0        20.00   0.50     0.60
# 492113                  1            0.0        20.50   0.50     0.60
# 492485                  1            0.0        20.50   0.00     0.60
# 493314                  1            0.0         1.23   0.00     0.60
# ...                   ...            ...          ...    ...      ...
# 27476246                1            2.3        13.00   3.75     3.55
# 27476247                1            0.6         5.00   3.75     3.55
# 27480831                2            4.5        15.50   2.75     3.55
# 27522650                1            2.6        11.00   2.75     3.55
# 28319946                1            0.0         3.00   2.00     1.00
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 492111           0.0           0.0                    0.0         21.60
# 492112           0.0           0.0                    0.0         21.10
# 492113           0.0           0.0                    0.0         21.60
# 492485           0.0           0.0                    0.0         21.10
# 493314           0.0           0.0                    0.0          1.83
# ...              ...           ...                    ...           ...
# 27476246         0.0           0.0                    0.0         20.30
# 27476247         0.0           0.0                    0.0         12.30
# 27480831         2.5           0.0                    0.0         24.30
# 27522650         2.0           0.0                    0.0         19.30
# 28319946         0.0           0.4                    0.0          6.40
#
#          payment_type    trip_type  congestion_surcharge  \
# 492111           Cash     Dispatch                  0.00
# 492112           Cash  Street-hail                  0.00
# 492113           Cash  Street-hail                  0.00
# 492485           Cash  Street-hail                  0.00
# 493314           Cash  Street-hail                  0.00
# ...               ...          ...                   ...
# 27476246      Dispute  Street-hail                  2.75
# 27476247         Cash  Street-hail                  2.75
# 27480831  Credit card  Street-hail                  2.75
# 27522650  Credit card  Street-hail                  2.75
# 28319946         Cash  Street-hail                  0.00
#
#                                      Vendor         Ratecode PU_Borough  \
# 492111    Creative Mobile Technologies, LLC           Newark    Unknown
# 492112    Creative Mobile Technologies, LLC           Newark    Unknown
# 492113    Creative Mobile Technologies, LLC           Newark    Unknown
# 492485    Creative Mobile Technologies, LLC           Newark     Queens
# 493314    Creative Mobile Technologies, LLC  Negotiated fare     Queens
# ...                                     ...              ...        ...
# 27476246  Creative Mobile Technologies, LLC    Standard rate  Manhattan
# 27476247  Creative Mobile Technologies, LLC    Standard rate  Manhattan
# 27480831  Creative Mobile Technologies, LLC    Standard rate  Manhattan
# 27522650  Creative Mobile Technologies, LLC    Standard rate  Manhattan
# 28319946                      Verifone Inc.    Standard rate     Queens
#
#                                  PU_Zone PU_service_zone DO_Borough  \
# 492111                           Unknown         Unknown    Unknown
# 492112                           Unknown         Unknown    Unknown
# 492113                           Unknown         Unknown    Unknown
# 492485    Long Island City/Hunters Point       Boro Zone     Queens
# 493314    Long Island City/Hunters Point       Boro Zone     Queens
# ...                                  ...             ...        ...
# 27476246         Two Bridges/Seward Park     Yellow Zone  Manhattan
# 27476247           Upper East Side North     Yellow Zone  Manhattan
# 27480831                        Gramercy     Yellow Zone  Manhattan
# 27522650                  Yorkville West     Yellow Zone  Manhattan
# 28319946         Queensbridge/Ravenswood       Boro Zone     Queens
#
#                                  DO_Zone DO_service_zone  total_amount_check  \
# 492111                           Unknown         Unknown               21.60
# 492112                           Unknown         Unknown               21.10
# 492113                           Unknown         Unknown               21.60
# 492485    Long Island City/Hunters Point       Boro Zone               21.10
# 493314    Long Island City/Hunters Point       Boro Zone                1.83
# ...                                  ...             ...                 ...
# 27476246         Two Bridges/Seward Park     Yellow Zone               23.05
# 27476247               East Harlem South       Boro Zone               15.05
# 27480831                        Gramercy     Yellow Zone               27.05
# 27522650                  Yorkville West     Yellow Zone               22.05
# 28319946         Queensbridge/Ravenswood       Boro Zone                6.40
#
#          total_amount_match?  total_amount_difference  trip_duration_mins
# 492111                 Match                     0.00            1.066667
# 492112                 Match                     0.00            0.300000
# 492113                 Match                     0.00            1.266667
# 492485                 Match                     0.00            2.600000
# 493314                 Match                     0.00            2.250000
# ...                      ...                      ...                 ...
# 27476246            No Match                    -2.75            0.100000
# 27476247            No Match                    -2.75            4.983333
# 27480831            No Match                    -2.75            0.000000
# 27522650            No Match                    -2.75            0.033333
# 28319946               Match                     0.00            0.800000
#
# [97 rows x 31 columns]

# %%
# Checking if there's any link between mta_tax and Ratecode using pivot table
pd.pivot_table(taxi_trips, index='Ratecode', columns='mta_tax', values='lpep_pickup_datetime', aggfunc='count', fill_value=0)
# Out:
# mta_tax                 0.00   0.07   0.08   0.09   0.10   0.11   0.12   \
# Ratecode
# Group ride                  6      0      0      0      0      0      0
# JFK                       395      0      0      0      0      0      0
# Nassau or Westchester     270      0      0      0      0      0      0
# Negotiated fare        481912      0      0      0      0      0      0
# Newark                  13764      0      0      0      0      0      0
# Standard rate           49870      5      6      2      1      6      1
# Unknown                529658      0      1      0      0      0      0
#
# mta_tax                0.13   0.18   0.25   0.32   0.36      0.50   0.55   \
# Ratecode
# Group ride                 0      0      0      0      0       343      0
# JFK                        0      0      0      0      0     55139      0
# Nassau or Westchester      0      0      0      0      0     18228      0
# Negotiated fare            0      0      0      0      0    258307      0
# Newark                     0      0      0      0      0         0      0
# Standard rate              1      1      5      1      1  26505388      5
# Unknown                    0      0      0      0      0    412694      0
#
# mta_tax                0.60   0.65   0.81   0.83   1.00   1.37   1.50   2.75   \
# Ratecode
# Group ride                 0      0      0      0      0      0      0      0
# JFK                        0      0      0      0      0      0      0      0
# Nassau or Westchester      0      0      0      0      0      0      0      0
# Negotiated fare            2      0      0      0      0      0      1      0
# Newark                     5      0      0      0      0      0      0      0
# Standard rate              0      1      1      1      1      1      0      1
# Unknown                    0      0      0      0      0      0      0      0
#
# mta_tax                3.55   3.80   4.41   17.33  26.22  82.91
# Ratecode
# Group ride                 0      0      0      0      0      0
# JFK                        0      0      0      0      0      0
# Nassau or Westchester      0      0      0      0      0      0
# Negotiated fare            0      0      0      0      0      0
# Newark                     0      0      0      0      0      0
# Standard rate             42      1      1      1      1      1
# Unknown                    0      0      0      0      0      0

# %%
# Checking if there's any link between mta_tax and Ratecode using pivot table
pd.pivot_table(taxi_trips, index='trip_type', columns='mta_tax', values='lpep_pickup_datetime', aggfunc='count', fill_value=0)
# Out:
# mta_tax       0.00   0.07   0.08   0.09   0.10   0.11   0.12   0.13   0.18   \
# trip_type
# Dispatch     495813      0      0      0      0      0      0      0      0
# Street-hail   50431      5      7      2      1      6      1      1      1
# Unknown      529631      0      0      0      0      0      0      0      0
#
# mta_tax      0.25   0.32   0.36      0.50   0.55   0.60   0.65   0.81   0.83   \
# trip_type
# Dispatch         0      0      0    247526      0      1      0      0      0
# Street-hail      5      1      1  26589551      5      6      1      1      1
# Unknown          0      0      0    413022      0      0      0      0      0
#
# mta_tax      1.00   1.37   1.50   2.75   3.55   3.80   4.41   17.33  26.22  \
# trip_type
# Dispatch         0      0      0      0      0      0      0      0      0
# Street-hail      1      1      1      1     42      1      1      1      1
# Unknown          0      0      0      0      0      0      0      0      0
#
# mta_tax      82.91
# trip_type
# Dispatch         0
# Street-hail      1
# Unknown          0

# %%
# Checking if there's any link between mta_tax and Ratecode using pivot table
pd.pivot_table(taxi_trips, index='payment_type', columns='mta_tax', values='lpep_pickup_datetime', aggfunc='count', fill_value=0)
# Out:
# mta_tax        0.00   0.07   0.08   0.09   0.10   0.11   0.12   0.13   0.18   \
# payment_type
# Cash          306534      5      6      2      1      6      1      0      1
# Credit card   226480      0      1      0      0      0      0      1      0
# Dispute         4445      0      0      0      0      0      0      0      0
# No charge       8644      0      0      0      0      0      0      0      0
# Unknown       529772      0      0      0      0      0      0      0      0
#
# mta_tax       0.25   0.32   0.36      0.50   0.55   0.60   0.65   0.81   \
# payment_type
# Cash              5      1      1  12086385      3      7      1      0
# Credit card       0      0      0  14567035      2      0      0      1
# Dispute           0      0      0     59520      0      0      0      0
# No charge         0      0      0    123566      0      0      0      0
# Unknown           0      0      0    413593      0      0      0      0
#
# mta_tax       0.83   1.00   1.37   1.50   2.75   3.55   3.80   4.41   17.33  \
# payment_type
# Cash              1      1      1      0      0     16      0      1      1
# Credit card       0      0      0      1      0     16      1      0      0
# Dispute           0      0      0      0      0      1      0      0      0
# No charge         0      0      0      0      1      9      0      0      0
# Unknown           0      0      0      0      0      0      0      0      0
#
# mta_tax       26.22  82.91
# payment_type
# Cash              1      1
# Credit card       0      0
# Dispute           0      0
# No charge         0      0
# Unknown           0      0

# %%
# Checking if there's any link between mta_tax and Ratecode using pivot table
pd.pivot_table(taxi_trips, index='total_amount_match?', columns='mta_tax', values='lpep_pickup_datetime', aggfunc='count', fill_value=0)
# Out:
# mta_tax                0.00   0.07   0.08   0.09   0.10   0.11   0.12   0.13   \
# total_amount_match?
# Match                1063518      5      7      2      1      6      1      1
# No Match               12357      0      0      0      0      0      0      0
#
# mta_tax              0.18   0.25   0.32   0.36      0.50   0.55   0.60   \
# total_amount_match?
# Match                    1      5      1      1  26671973      5      7
# No Match                 0      0      0      0    578126      0      0
#
# mta_tax              0.65   0.81   0.83   1.00   1.37   1.50   2.75   3.55   \
# total_amount_match?
# Match                    1      1      1      1      1      1      1      1
# No Match                 0      0      0      0      0      0      0     41
#
# mta_tax              3.80   4.41   17.33  26.22  82.91
# total_amount_match?
# Match                    1      1      1      0      1
# No Match                 0      0      0      1      0

# %% [markdown]
# From the above pivot table, we can see that the total_amount for 42 records where the mta_tax isn't 0.00 or 0.50, doesn't match with the total_amount_check. Let's check those 42 records first.

# %%
# Checking the rows where the mta_tax is not 0.50 or 0.00 and where the total_amount_match? is No Match
taxi_trips.loc[~(taxi_trips['mta_tax']==0.50) & ~(taxi_trips['mta_tax']==0.00) & (taxi_trips['total_amount_match?']=='No Match')]
# Out:
#           VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 12271127         1  2018-04-28 22:25:49   2018-04-28 22:30:30
# 21164280         1  2019-04-29 18:25:53   2019-04-29 18:25:55
# 21164282         1  2019-05-19 19:29:21   2019-05-19 19:29:23
# 21164284         1  2019-05-21 00:09:20   2019-05-21 00:09:23
# 21164285         1  2019-05-25 16:32:38   2019-05-25 16:32:43
# 21164286         1  2019-05-25 16:34:14   2019-05-25 16:34:20
# 21164287         1  2019-05-25 18:12:20   2019-05-25 18:12:26
# 21164288         1  2019-05-25 18:59:49   2019-05-25 18:59:53
# 21164289         1  2019-05-27 17:26:56   2019-05-27 17:26:59
# 21164290         1  2019-06-11 19:25:24   2019-06-11 19:25:30
# 22092463         1  2019-11-10 15:51:03   2019-11-10 15:51:06
# 22092465         1  2019-12-14 04:55:29   2019-12-14 04:55:29
# 22092467         1  2019-12-30 20:15:05   2019-12-30 20:15:08
# 22361775         1  2019-12-14 15:41:10   2019-12-14 15:41:13
# 23032958         1  2019-09-19 19:59:30   2019-09-19 19:59:36
# 23032959         1  2019-11-03 21:36:36   2019-11-03 21:36:40
# 23035437         1  2019-09-21 03:08:47   2019-09-21 03:08:50
# 23035438         1  2019-09-21 12:57:41   2019-09-21 12:57:47
# 24089236         1  2019-07-13 23:29:45   2019-07-13 23:29:53
# 24089244         1  2019-08-12 10:26:32   2019-08-12 10:26:36
# 24089245         1  2019-08-19 05:57:42   2019-08-19 05:57:42
# 24089246         1  2019-08-29 14:04:31   2019-08-29 14:04:54
# 24091222         1  2019-06-22 08:40:57   2019-06-22 08:41:00
# 24091233         1  2019-07-19 01:40:34   2019-07-19 01:40:36
# 24091252         1  2019-08-25 01:46:45   2019-08-25 01:46:50
# 24091254         1  2019-08-30 20:48:26   2019-08-30 20:48:31
# 25050726         1  2019-03-08 20:01:09   2019-03-08 20:01:17
# 25050768         1  2019-04-06 20:07:00   2019-04-06 20:07:03
# 25195278         1  2019-03-21 15:24:24   2019-03-21 15:24:24
# 25195279         1  2019-03-21 22:32:14   2019-03-21 22:33:25
# 26092854         1  2019-02-07 11:18:30   2019-02-07 11:35:44
# 26092855         1  2019-02-07 11:44:12   2019-02-07 11:45:15
# 26092862         1  2019-02-12 13:50:12   2019-02-12 13:50:18
# 26246980         1  2019-02-16 17:51:13   2019-02-16 17:51:13
# 27214872         1  2020-01-12 18:36:33   2020-01-12 18:36:37
# 27214873         1  2020-02-15 15:09:32   2020-02-15 15:09:32
# 27214874         1  2020-03-31 09:42:33   2020-03-31 09:42:35
# 27214875         1  2020-09-15 09:22:21   2020-09-15 09:22:21
# 27476246         1  2020-01-28 19:16:01   2020-01-28 19:16:07
# 27476247         1  2020-06-13 10:59:11   2020-06-13 11:04:10
# 27480831         1  2020-01-01 10:58:27   2020-01-01 10:58:27
# 27522650         1  2020-01-18 14:13:47   2020-01-18 14:13:49
#
#          store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 12271127                  N           1            82           129
# 21164280                  N           1           230           230
# 21164282                  N           1           162           162
# 21164284                  N           1           107           107
# 21164285                  N           1           186           186
# 21164286                  N           1           186           186
# 21164287                  N           1           144           144
# 21164288                  N           1           161           161
# 21164289                  N           1           232           232
# 21164290                  N           1           261           261
# 22092463                  Y           1           209           209
# 22092465                  Y           1           211           264
# 22092467                  N           1           141           141
# 22361775                  N           1           239           239
# 23032958                  N           1           236           236
# 23032959                  Y           1           263           263
# 23035437                  N           1            79            79
# 23035438                  N           1           239           239
# 24089236                  N           1           246           246
# 24089244                  N           1           236           236
# 24089245                  Y           1           170           264
# 24089246                  N           1           238           238
# 24091222                  N           1            50            50
# 24091233                  N           1           107           107
# 24091252                  N           1           161           161
# 24091254                  N           1           142           142
# 25050726                  N           1           263           263
# 25050768                  N           1           107           107
# 25195278                  N           1           239           239
# 25195279                  N           1           239           239
# 26092854                  N           1            12           145
# 26092855                  N           1            12            12
# 26092862                  N           1           263           263
# 26246980                  N           1           262           262
# 27214872                  Y           1           211           211
# 27214873                  Y           1           144           264
# 27214874                  N           1           236           236
# 27214875                  Y           1           237           264
# 27476246                  N           1           232           232
# 27476247                  N           1           236            75
# 27480831                  N           1           107           107
# 27522650                  N           1           263           263
#
#           passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 12271127                1            1.3       3005.0  25.42    26.22
# 21164280                1            8.2         30.0   3.75     3.55
# 21164282                1            5.6         21.0   2.75     3.55
# 21164284                1            8.5         36.5   3.25     3.55
# 21164285                1            7.0         28.0   2.75     3.55
# 21164286                1            7.1         28.5   2.75     3.55
# 21164287                1            3.2         15.0   2.75     3.55
# 21164288                1            6.4         21.5   2.75     3.55
# 21164289                1            3.9         13.5   2.75     3.55
# 21164290                1            2.2          9.5   3.75     3.55
# 22092463                1            2.1          9.5   2.75     3.55
# 22092465                1            0.0         12.5   3.25     3.55
# 22092467                4            4.4         17.0   3.75     3.55
# 22361775                2           14.5         43.0   2.75     3.55
# 23032958                1            2.1          9.0   3.75     3.55
# 23032959                1            5.9         20.0   3.25     3.55
# 23035437                1            6.0         21.0   3.25     3.55
# 23035438                1            1.7          9.0   2.75     3.55
# 24089236                1            3.8         14.0   3.25     3.55
# 24089244                1            2.0          8.5   2.75     3.55
# 24089245                1            0.0          2.5   2.75     3.55
# 24089246                1            2.0          9.5   3.25     3.55
# 24091222                1            5.2         18.5   2.75     3.55
# 24091233                1            4.3         16.0   3.25     3.55
# 24091252                1            5.6         20.5   3.25     3.55
# 24091254                1            3.5         15.0   3.25     3.55
# 25050726                1            9.7          2.5   3.25     3.55
# 25050768                1            7.0         24.5   2.75     3.55
# 25195278                1            3.6         17.0   2.75     3.55
# 25195279                1            2.6         12.0   3.25     3.55
# 26092854                1            0.0         11.0   2.75     3.55
# 26092855                1            0.0          3.0   2.75     3.55
# 26092862                1            1.7          8.0   2.75     3.55
# 26246980                1            2.6         11.0   3.75     3.55
# 27214872                1            3.5         17.5   2.75     3.55
# 27214873                1            0.0         14.0   2.75     3.55
# 27214874                1            2.4          9.0   2.75     3.55
# 27214875                1            0.0         13.0   2.75     3.55
# 27476246                1            2.3         13.0   3.75     3.55
# 27476247                1            0.6          5.0   3.75     3.55
# 27480831                2            4.5         15.5   2.75     3.55
# 27522650                1            2.6         11.0   2.75     3.55
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 12271127        0.00          0.00                    0.0       3005.80
# 21164280        0.00          0.00                    0.0         37.30
# 21164282        0.00          0.00                    0.0         27.30
# 21164284        0.00          0.00                    0.0         43.30
# 21164285        0.00          0.00                    0.0         34.30
# 21164286        0.00          0.00                    0.0         34.80
# 21164287        0.00          0.00                    0.0         21.30
# 21164288        0.00          0.00                    0.0         27.80
# 21164289        0.00          0.00                    0.0         19.80
# 21164290        0.00          0.00                    0.0         16.80
# 22092463        0.00          0.00                    0.0         15.80
# 22092465        0.00          0.00                    0.0         19.30
# 22092467        2.43          0.00                    0.0         26.73
# 22361775        8.00          6.12                    0.0         63.42
# 23032958        0.00          0.00                    0.0         16.30
# 23032959        0.00          0.00                    0.0         26.80
# 23035437       10.00          0.00                    0.0         37.80
# 23035438        1.50          0.00                    0.0         16.80
# 24089236        0.00          0.00                    0.0         20.80
# 24089244        0.00          0.00                    0.0         14.80
# 24089245        0.00          0.00                    0.0          8.80
# 24089246        0.00          0.00                    0.0         16.30
# 24091222        4.95          0.00                    0.0         29.75
# 24091233        3.00          0.00                    0.0         25.80
# 24091252        5.45          0.00                    0.0         32.75
# 24091254        4.50          0.00                    0.0         26.30
# 25050726        0.00          0.00                    0.0          9.30
# 25050768        0.00          0.00                    0.0         30.80
# 25195278        4.65          0.00                    0.0         27.95
# 25195279        3.75          0.00                    0.0         22.55
# 26092854        0.00          0.00                    0.0         17.30
# 26092855        0.00          0.00                    0.0          9.30
# 26092862        0.00          0.00                    0.0         14.30
# 26246980        3.65          0.00                    0.0         21.95
# 27214872        0.00          0.00                    0.0         23.80
# 27214873        0.00          0.00                    0.0         20.30
# 27214874        0.00          0.00                    0.0         15.30
# 27214875        0.00          0.00                    0.0         19.30
# 27476246        0.00          0.00                    0.0         20.30
# 27476247        0.00          0.00                    0.0         12.30
# 27480831        2.50          0.00                    0.0         24.30
# 27522650        2.00          0.00                    0.0         19.30
#
#          payment_type    trip_type  congestion_surcharge  \
# 12271127         Cash  Street-hail                  0.00
# 21164280         Cash  Street-hail                  2.75
# 21164282    No charge  Street-hail                  2.75
# 21164284         Cash  Street-hail                  2.75
# 21164285    No charge  Street-hail                  2.75
# 21164286    No charge  Street-hail                  2.75
# 21164287    No charge  Street-hail                  2.75
# 21164288    No charge  Street-hail                  2.75
# 21164289    No charge  Street-hail                  2.75
# 21164290    No charge  Street-hail                  2.75
# 22092463         Cash  Street-hail                  2.75
# 22092465         Cash  Street-hail                  2.75
# 22092467  Credit card  Street-hail                  2.75
# 22361775  Credit card  Street-hail                  2.75
# 23032958         Cash  Street-hail                  2.75
# 23032959         Cash  Street-hail                  2.75
# 23035437  Credit card  Street-hail                  2.75
# 23035438  Credit card  Street-hail                  2.75
# 24089236    No charge  Street-hail                  2.75
# 24089244  Credit card  Street-hail                  2.75
# 24089245         Cash  Street-hail                  2.75
# 24089246         Cash  Street-hail                  2.75
# 24091222  Credit card  Street-hail                  2.75
# 24091233  Credit card  Street-hail                  2.75
# 24091252  Credit card  Street-hail                  2.75
# 24091254  Credit card  Street-hail                  2.75
# 25050726         Cash  Street-hail                  2.75
# 25050768    No charge  Street-hail                  2.75
# 25195278  Credit card  Street-hail                  2.75
# 25195279  Credit card  Street-hail                  2.75
# 26092854         Cash  Street-hail                  2.75
# 26092855         Cash  Street-hail                  2.75
# 26092862         Cash  Street-hail                  2.75
# 26246980  Credit card  Street-hail                  2.75
# 27214872         Cash  Street-hail                  2.75
# 27214873         Cash  Street-hail                  2.75
# 27214874  Credit card  Street-hail                  2.75
# 27214875         Cash  Street-hail                  2.75
# 27476246      Dispute  Street-hail                  2.75
# 27476247         Cash  Street-hail                  2.75
# 27480831  Credit card  Street-hail                  2.75
# 27522650  Credit card  Street-hail                  2.75
#
#                                      Vendor       Ratecode PU_Borough  \
# 12271127  Creative Mobile Technologies, LLC  Standard rate     Queens
# 21164280  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 21164282  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 21164284  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 21164285  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 21164286  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 21164287  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 21164288  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 21164289  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 21164290  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 22092463  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 22092465  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 22092467  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 22361775  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 23032958  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 23032959  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 23035437  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 23035438  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 24089236  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 24089244  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 24089245  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 24089246  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 24091222  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 24091233  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 24091252  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 24091254  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 25050726  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 25050768  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 25195278  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 25195279  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 26092854  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 26092855  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 26092862  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 26246980  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 27214872  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 27214873  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 27214874  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 27214875  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 27476246  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 27476247  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 27480831  Creative Mobile Technologies, LLC  Standard rate  Manhattan
# 27522650  Creative Mobile Technologies, LLC  Standard rate  Manhattan
#
#                                PU_Zone PU_service_zone DO_Borough  \
# 12271127                      Elmhurst       Boro Zone     Queens
# 21164280     Times Sq/Theatre District     Yellow Zone  Manhattan
# 21164282                  Midtown East     Yellow Zone  Manhattan
# 21164284                      Gramercy     Yellow Zone  Manhattan
# 21164285  Penn Station/Madison Sq West     Yellow Zone  Manhattan
# 21164286  Penn Station/Madison Sq West     Yellow Zone  Manhattan
# 21164287           Little Italy/NoLiTa     Yellow Zone  Manhattan
# 21164288                Midtown Center     Yellow Zone  Manhattan
# 21164289       Two Bridges/Seward Park     Yellow Zone  Manhattan
# 21164290            World Trade Center     Yellow Zone  Manhattan
# 22092463                       Seaport     Yellow Zone  Manhattan
# 22092465                          SoHo     Yellow Zone    Unknown
# 22092467               Lenox Hill West     Yellow Zone  Manhattan
# 22361775         Upper West Side South     Yellow Zone  Manhattan
# 23032958         Upper East Side North     Yellow Zone  Manhattan
# 23032959                Yorkville West     Yellow Zone  Manhattan
# 23035437                  East Village     Yellow Zone  Manhattan
# 23035438         Upper West Side South     Yellow Zone  Manhattan
# 24089236     West Chelsea/Hudson Yards     Yellow Zone  Manhattan
# 24089244         Upper East Side North     Yellow Zone  Manhattan
# 24089245                   Murray Hill     Yellow Zone    Unknown
# 24089246         Upper West Side North     Yellow Zone  Manhattan
# 24091222                  Clinton West     Yellow Zone  Manhattan
# 24091233                      Gramercy     Yellow Zone  Manhattan
# 24091252                Midtown Center     Yellow Zone  Manhattan
# 24091254           Lincoln Square East     Yellow Zone  Manhattan
# 25050726                Yorkville West     Yellow Zone  Manhattan
# 25050768                      Gramercy     Yellow Zone  Manhattan
# 25195278         Upper West Side South     Yellow Zone  Manhattan
# 25195279         Upper West Side South     Yellow Zone  Manhattan
# 26092854                  Battery Park     Yellow Zone     Queens
# 26092855                  Battery Park     Yellow Zone  Manhattan
# 26092862                Yorkville West     Yellow Zone  Manhattan
# 26246980                Yorkville East     Yellow Zone  Manhattan
# 27214872                          SoHo     Yellow Zone  Manhattan
# 27214873           Little Italy/NoLiTa     Yellow Zone    Unknown
# 27214874         Upper East Side North     Yellow Zone  Manhattan
# 27214875         Upper East Side South     Yellow Zone    Unknown
# 27476246       Two Bridges/Seward Park     Yellow Zone  Manhattan
# 27476247         Upper East Side North     Yellow Zone  Manhattan
# 27480831                      Gramercy     Yellow Zone  Manhattan
# 27522650                Yorkville West     Yellow Zone  Manhattan
#
#                                  DO_Zone DO_service_zone  total_amount_check  \
# 12271127                 Jackson Heights       Boro Zone             3056.64
# 21164280       Times Sq/Theatre District     Yellow Zone               40.05
# 21164282                    Midtown East     Yellow Zone               30.05
# 21164284                        Gramercy     Yellow Zone               46.05
# 21164285    Penn Station/Madison Sq West     Yellow Zone               37.05
# 21164286    Penn Station/Madison Sq West     Yellow Zone               37.55
# 21164287             Little Italy/NoLiTa     Yellow Zone               24.05
# 21164288                  Midtown Center     Yellow Zone               30.55
# 21164289         Two Bridges/Seward Park     Yellow Zone               22.55
# 21164290              World Trade Center     Yellow Zone               19.55
# 22092463                         Seaport     Yellow Zone               18.55
# 22092465                              NV         Unknown               22.05
# 22092467                 Lenox Hill West     Yellow Zone               29.48
# 22361775           Upper West Side South     Yellow Zone               66.17
# 23032958           Upper East Side North     Yellow Zone               19.05
# 23032959                  Yorkville West     Yellow Zone               29.55
# 23035437                    East Village     Yellow Zone               40.55
# 23035438           Upper West Side South     Yellow Zone               19.55
# 24089236       West Chelsea/Hudson Yards     Yellow Zone               23.55
# 24089244           Upper East Side North     Yellow Zone               17.55
# 24089245                              NV         Unknown               11.55
# 24089246           Upper West Side North     Yellow Zone               19.05
# 24091222                    Clinton West     Yellow Zone               32.50
# 24091233                        Gramercy     Yellow Zone               28.55
# 24091252                  Midtown Center     Yellow Zone               35.50
# 24091254             Lincoln Square East     Yellow Zone               29.05
# 25050726                  Yorkville West     Yellow Zone               12.05
# 25050768                        Gramercy     Yellow Zone               33.55
# 25195278           Upper West Side South     Yellow Zone               30.70
# 25195279           Upper West Side South     Yellow Zone               25.30
# 26092854  Long Island City/Hunters Point       Boro Zone               20.05
# 26092855                    Battery Park     Yellow Zone               12.05
# 26092862                  Yorkville West     Yellow Zone               17.05
# 26246980                  Yorkville East     Yellow Zone               24.70
# 27214872                            SoHo     Yellow Zone               26.55
# 27214873                              NV         Unknown               23.05
# 27214874           Upper East Side North     Yellow Zone               18.05
# 27214875                              NV         Unknown               22.05
# 27476246         Two Bridges/Seward Park     Yellow Zone               23.05
# 27476247               East Harlem South       Boro Zone               15.05
# 27480831                        Gramercy     Yellow Zone               27.05
# 27522650                  Yorkville West     Yellow Zone               22.05
#
#          total_amount_match?  total_amount_difference  trip_duration_mins
# 12271127            No Match                   -50.84            4.683333
# 21164280            No Match                    -2.75            0.033333
# 21164282            No Match                    -2.75            0.033333
# 21164284            No Match                    -2.75            0.050000
# 21164285            No Match                    -2.75            0.083333
# 21164286            No Match                    -2.75            0.100000
# 21164287            No Match                    -2.75            0.100000
# 21164288            No Match                    -2.75            0.066667
# 21164289            No Match                    -2.75            0.050000
# 21164290            No Match                    -2.75            0.100000
# 22092463            No Match                    -2.75            0.050000
# 22092465            No Match                    -2.75            0.000000
# 22092467            No Match                    -2.75            0.050000
# 22361775            No Match                    -2.75            0.050000
# 23032958            No Match                    -2.75            0.100000
# 23032959            No Match                    -2.75            0.066667
# 23035437            No Match                    -2.75            0.050000
# 23035438            No Match                    -2.75            0.100000
# 24089236            No Match                    -2.75            0.133333
# 24089244            No Match                    -2.75            0.066667
# 24089245            No Match                    -2.75            0.000000
# 24089246            No Match                    -2.75            0.383333
# 24091222            No Match                    -2.75            0.050000
# 24091233            No Match                    -2.75            0.033333
# 24091252            No Match                    -2.75            0.083333
# 24091254            No Match                    -2.75            0.083333
# 25050726            No Match                    -2.75            0.133333
# 25050768            No Match                    -2.75            0.050000
# 25195278            No Match                    -2.75            0.000000
# 25195279            No Match                    -2.75            1.183333
# 26092854            No Match                    -2.75           17.233333
# 26092855            No Match                    -2.75            1.050000
# 26092862            No Match                    -2.75            0.100000
# 26246980            No Match                    -2.75            0.000000
# 27214872            No Match                    -2.75            0.066667
# 27214873            No Match                    -2.75            0.000000
# 27214874            No Match                    -2.75            0.033333
# 27214875            No Match                    -2.75            0.000000
# 27476246            No Match                    -2.75            0.100000
# 27476247            No Match                    -2.75            4.983333
# 27480831            No Match                    -2.75            0.000000
# 27522650            No Match                    -2.75            0.033333

# %%
# Checking the total_amount_difference values where the mta_tax is not 0.50 or 0.00 and where the total_amount_match? is No Match
taxi_trips.loc[~(taxi_trips['mta_tax']==0.50) & ~(taxi_trips['mta_tax']==0.00) & (taxi_trips['total_amount_match?']=='No Match')].round(2).groupby(['mta_tax','total_amount_difference']).count()['VendorID']
# Out:
# mta_tax  total_amount_difference
# 3.55     -2.75                      41
# 26.22    -50.84                      1
# Name: VendorID, dtype: int64

# %% [markdown]
# total_amount for 41 of those records were 2.75 less than total_amount_check. All 41 of those records were charged 2.75 as congestion_surcharge. Removing the congestion_surcharge of 2.75 would help match the total_amount with total_amount_check but this wouldn't be correct because mta_tax should never be values other than 0.00 or 0.50.
#
# So, what would be the total_amount_difference if we are to update the 3.55 as 0.50? <br>
# 37.30 - (40.05 - 3.55 + 0.50) = 0.30
#
# 0.30 would be the total_amount_difference for the first record if we are to update the 3.55 as 0.50. Let's check if the total_amount_difference is 0.30 for the other 40 records.

# %%
# Assigning the 41 rows to a new variable to check what the total_amount would be after updating the values
mta_tax_check = taxi_trips.loc[~(taxi_trips['mta_tax']==0.50) & ~(taxi_trips['mta_tax']==0.00) & (taxi_trips['total_amount_difference'].round(2)==-2.75), ['fare_amount','extra','mta_tax','tip_amount','tolls_amount','improvement_surcharge','congestion_surcharge','total_amount','total_amount_check','total_amount_difference']]

mta_tax_check['total_amount_difference_after_update'] = mta_tax_check['total_amount'] - (mta_tax_check['total_amount_check'] - mta_tax_check['mta_tax'] + 0.50)

mta_tax_check['total_amount_difference_after_update'].round(1).value_counts()
# Out:
# 0.3    41
# Name: total_amount_difference_after_update, dtype: int64

# %% [markdown]
# For all 41 records, the total_amount_difference if we are to update the 3.55 as 0.50 would be 0.30. Therefore, we can update the mta_tax as 0.50 and improvement_surcharge as 0.30 where improvement_surcharge is 0.

# %%
# Getting the index numbers of rows to update
improvement_surcharge_to_update = taxi_trips.loc[(taxi_trips['mta_tax']==3.55) & (taxi_trips['total_amount_difference'].round(2)==-2.75) & (taxi_trips['improvement_surcharge']==0.0), 'improvement_surcharge'].index.to_list()

# Updating mta_tax as 0.5 using the index numbers
taxi_trips.loc[improvement_surcharge_to_update, 'mta_tax'] = 0.5

# Updating improvement_surcharge as 0.3 using the index numbers
taxi_trips.loc[improvement_surcharge_to_update, 'improvement_surcharge'] = 0.3

# %%
# Checking the rows again where the mta_tax is not 0.50 or 0.00 and where the total_amount_match? is No Match
taxi_trips.loc[~(taxi_trips['mta_tax']==0.50) & ~(taxi_trips['mta_tax']==0.00) & (taxi_trips['total_amount_match?']=='No Match')]
# Out:
#           VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 12271127         1  2018-04-28 22:25:49   2018-04-28 22:30:30
#
#          store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 12271127                  N           1            82           129
#
#           passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 12271127                1            1.3       3005.0  25.42    26.22
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 12271127         0.0           0.0                    0.0        3005.8
#
#          payment_type    trip_type  congestion_surcharge  \
# 12271127         Cash  Street-hail                   0.0
#
#                                      Vendor       Ratecode PU_Borough  \
# 12271127  Creative Mobile Technologies, LLC  Standard rate     Queens
#
#            PU_Zone PU_service_zone DO_Borough          DO_Zone  \
# 12271127  Elmhurst       Boro Zone     Queens  Jackson Heights
#
#          DO_service_zone  total_amount_check total_amount_match?  \
# 12271127       Boro Zone             3056.64            No Match
#
#           total_amount_difference  trip_duration_mins
# 12271127                   -50.84            4.683333

# %% [markdown]
# Now, we are left with one record where the mta_tax is not 0.50 or 0.00 and where the total_amount_match? is No Match. The fare_amount for this row needs investigation as it isn't possible for a trip with the distance of 1.3 miles to have fare_amount of 3005. We will invetigate this later. But for now, we will update the mta_tax to be either 0 or 0.50.

# %%
# Checking if there's any link between mta_tax and Ratecode using pivot table
pd.pivot_table(taxi_trips.loc[taxi_trips['Ratecode']=='Standard rate'], index='Ratecode', columns='mta_tax', values='lpep_pickup_datetime', aggfunc='count', fill_value=0)
# Out:
# mta_tax        0.00   0.07   0.08   0.09   0.10   0.11   0.12   0.13   0.18   \
# Ratecode
# Standard rate  49870      5      6      2      1      6      1      1      1
#
# mta_tax        0.25   0.32   0.36      0.50   0.55   0.65   0.81   0.83   \
# Ratecode
# Standard rate      5      1      1  26505429      5      1      1      1
#
# mta_tax        1.00   1.37   2.75   3.55   3.80   4.41   17.33  26.22  82.91
# Ratecode
# Standard rate      1      1      1      1      1      1      1      1      1

# %% [markdown]
# MTA tax is automatically triggered based on the metered rate in use and from the above pivot table, we can see 99.8% of standard rate trips had 0.50 MTA tax. So we will update the 26.22 as 0.50 rather than 0.

# %%
# Checking the rows again where the mta_tax is not 0.50 or 0.00 and where the total_amount_match? is No Match
taxi_trips.loc[(taxi_trips['mta_tax']==26.22) & (taxi_trips['total_amount_match?']=='No Match'), 'mta_tax'] = 0.5

# %%
# Checking the total_amount_difference values where the mta_tax is not 0.50 or 0.00 and where the total_amount_match? is No Match
taxi_trips.loc[~(taxi_trips['mta_tax']==0.50) & ~(taxi_trips['mta_tax']==0.00)].round(2).groupby('total_amount_match?').count()['VendorID']
# Out:
# total_amount_match?
# Match    55
# Name: VendorID, dtype: int64

# %% [markdown]
# All unrecognised values of mta_tax in No Match category has been updated. Now, let's move on to the 55 rows where the total_amount_match? is Match.

# %% [markdown]
# ---

# %% [markdown]
# To be continued...
